# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls
# Out:
# data  drive  sample_data

# %% [markdown]
# Import libraries

# %%
# and put in a ``data/`` directory under the current directory.
#
# After that, let’s import some necessities.
#

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math
import json
import re
# %matplotlib inline
USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Load & Preprocess Data
#
# The next step is to reformat our data file and load the data into
# structures that we can work with.
#
# The [WikiQACorpus](https://www.microsoft.com/en-us/download/details.aspx?id=52419)_
# is a rich dataset of Question Answering

# %%
corpus_name = "WikiQACorpus"
corpus = os.path.join("drive/MyDrive/data", corpus_name)

def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

printLines(os.path.join(corpus, "WikiQA-train.tsv"))
# Out:
# b'QuestionID\tQuestion\tDocumentID\tDocumentTitle\tSentenceID\tSentence\tLabel\n'
# b'Q1\thow are glacier caves formed?\tD1\tGlacier cave\tD1-0\tA partly submerged glacier cave on Perito Moreno Glacier .\t0\n'
# b'Q1\thow are glacier caves formed?\tD1\tGlacier cave\tD1-1\tThe ice facade is approximately 60 m high\t0\n'
# b'Q1\thow are glacier caves formed?\tD1\tGlacier cave\tD1-2\tIce formations in the Titlis glacier cave\t0\n'
# b'Q1\thow are glacier caves formed?\tD1\tGlacier cave\tD1-3\tA glacier cave is a cave formed within the ice of a glacier .\t1\n'
# b'Q1\thow are glacier caves formed?\tD1\tGlacier cave\tD1-4\tGlacier caves are often called ice caves , but this term is properly used to describe bedrock caves that contain year-round ice.\t0\n'
# b'Q2\tHow are the directions of the velocity and force vectors related in a circular motion\tD2\tCircular motion\tD2-0\tIn physics , circular motion is a movement of an object along the circumference of a circle or rotation along a circular path.\t0\n'
# b'Q2\tHow are the directions of the velocity and force vectors related in a circular motion\tD2\tCircular motion\tD2-1\tIt can be uniform, with constant angular rate of rotation (and constant speed), or non-uniform with a changing rate of rotation.\t0\n'
# b'Q2\tHow are the directions of the velocity and force vectors related in a circular motion\tD2\tCircular motion\tD2-2\tThe rotation around a fixed axis of a three-dimensional body involves circular motion of its parts.\t0\n'
# b'Q2\tHow are the directions of the velocity and force vectors related in a circular motion\tD2\tCircular motion\tD2-3\tThe equations of motion describe the movement of the center of mass of a body.\t0\n'

# %%
lines = []
conversations = {}
flag=1
fileName=os.path.join(corpus, "WikiQA-train.tsv")
with open(fileName, 'r', encoding='iso-8859-1') as f:
    for line in f:
        if (flag>1):
          result=re.split(r'\t+', line)
          lines.append(result[1]+'\t'+result[5])
        else:
          flag+=1
flag=1
fileName=os.path.join(corpus, "WikiQA-dev.tsv")
with open(fileName, 'r', encoding='iso-8859-1') as f:
    for line in f:
        if (flag>1):
          result=re.split(r'\t+', line)
          lines.append(result[1]+'\t'+result[5])
        else:
          flag+=1
flag=1
fileName=os.path.join(corpus, "WikiQA-test.tsv")
with open(fileName, 'r', encoding='iso-8859-1') as f:
    for line in f:
        if (flag>1):
          result=re.split(r'\t+', line)
          lines.append(result[1]+'\t'+result[5])
        else:
          flag+=1

# %%
datafile = os.path.join(corpus, "formatted_wiki_lines.txt")
with open(datafile, 'w', encoding='utf-8') as outputfile:
    for pair in lines:
        outputfile.write("%s\n" % pair)

# %%
corpus_name = "WikiQACorpus"
corpus = os.path.join("drive/MyDrive/data", corpus_name)
datafile = os.path.join(corpus, "formatted_wiki_lines.txt")

# %% [markdown]
# ### Load and trim data
#
# Our next order of business is to create a vocabulary and load
# query/response sentence pairs into memory.
#
# Note that we are dealing with sequences of **words**, which do not have
# an implicit mapping to a discrete numerical space. Thus, we must create
# one by mapping each unique word that we encounter in our dataset to an
# index value.
#
# For this we define a ``Voc`` class, which keeps a mapping from words to
# indexes, a reverse mapping of indexes to words, a count of each word and
# a total word count. The class provides methods for adding a word to the
# vocabulary (``addWord``), adding all words in a sentence
# (``addSentence``) and trimming infrequently seen words (``trim``). More
# on trimming later.

# %%
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token

class Voc:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []

        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3 # Count default tokens

        for word in keep_words:
            self.addWord(word)

# %% [markdown]
# Now we can assemble our vocabulary and query/response sentence pairs.
# Before we are ready to use this data, we must perform some
# preprocessing.
#
# First, we must convert the Unicode strings to ASCII using
# ``unicodeToAscii``. Next, we should convert all letters to lowercase and
# trim all non-letter characters except for basic punctuation
# (``normalizeString``). Finally, to aid in training convergence, we will
# filter out sentences with length greater than the ``MAX_LENGTH``
# threshold (``filterPairs``).

# %%
MAX_LENGTH = 15  # Maximum sentence length to consider

# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

# Read query/response pairs and return a voc object
def readVocs(datafile, corpus_name):
    print("Reading lines...")
    # Read the file and split into lines
    lines = open(datafile, encoding='utf-8').\
        read().strip().split('\n')
    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    voc = Voc(corpus_name)
    return voc, pairs

# Returns True iff both sentences in a pair 'p' are under the MAX_LENGTH threshold
def filterPair(p):
    # Input sequences need to preserve the last word for EOS token
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

# Filter pairs using filterPair condition
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# Using the functions defined above, return a populated voc object and pairs list
def loadPrepareData(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    voc, pairs = readVocs(datafile, corpus_name)
    print("Read {!s} sentence pairs".format(len(pairs)))
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    print("Counting words...")
    for pair in pairs:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])
    print("Counted words:", voc.num_words)
    return voc, pairs


# Load/Assemble voc and pairs
save_dir = os.path.join("data", "save")
voc, pairs = loadPrepareData(corpus, corpus_name, datafile, save_dir)
# Print some pairs to validate
print("\npairs:")
for pair in pairs[:10]:
    print(pair)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 29258 sentence pairs
# Trimmed to 6779 sentence pairs
# Counting words...
# Counted words: 12525
#
# pairs:
# ['how are glacier caves formed ?', 'a partly submerged glacier cave on perito moreno glacier .']
# ['how are glacier caves formed ?', 'the ice facade is approximately m high']
# ['how are glacier caves formed ?', 'ice formations in the titlis glacier cave']
# ['how are glacier caves formed ?', 'a glacier cave is a cave formed within the ice of a glacier .']
# ['how did apollo creed die', 'he was played by carl weathers .']
# ['how did apollo creed die', 'all of apollo s championship fights were scheduled for the round distance .']
# ['how did apollo creed die', 'championship fights did not convert from rounds to rounds until .']
# ['how long is the term for federal judges', 'see article i and article iii tribunals .']
# ['how a beretta model pistols magazines works', 'it is a further development of the beretta model whose production ended in .']
# ['how a vul works', 'this is yet another key advantage of vul over whole life .']

# %% [markdown]
# Another tactic that is beneficial to achieving faster convergence during
# training is trimming rarely used words out of our vocabulary. Decreasing
# the feature space will also soften the difficulty of the function that
# the model must learn to approximate. We will do this as a two-step
# process:
#
# 1) Trim words used under ``MIN_COUNT`` threshold using the ``voc.trim``
#    function.
#
# 2) Filter out pairs with trimmed words.

# %%
MIN_COUNT = 3    # Minimum word count threshold for trimming

def trimRareWords(voc, pairs, MIN_COUNT):
    # Trim words used under the MIN_COUNT from the voc
    voc.trim(MIN_COUNT)
    # Filter out pairs with trimmed words
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        # Check input sentence
        for word in input_sentence.split(' '):
            if word not in voc.word2index:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word2index:
                keep_output = False
                break

        # Only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("Trimmed from {} pairs to {}, {:.4f} of total".format(len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)))
    return keep_pairs


# Trim voc and pairs
pairs = trimRareWords(voc, pairs, MIN_COUNT)
# Out:
# keep_words 4978 / 12522 = 0.3975
# Trimmed from 6779 pairs to 2113, 0.3117 of total

# %% [markdown]
# ## Prepare Data for Models
#
# Although we have put a great deal of effort into preparing and massaging our
# data into a nice vocabulary object and list of sentence pairs, our models
# will ultimately expect numerical torch tensors as inputs. One way to
# prepare the processed data for the models can be found in the [seq2seq
# translation
# tutorial](https://pytorch.org/tutorials/intermediate/seq2seq_translation_tutorial.html)_.
# In that tutorial, we use a batch size of 1, meaning that all we have to
# do is convert the words in our sentence pairs to their corresponding
# indexes from the vocabulary and feed this to the models.
#
# However, if you’re interested in speeding up training and/or would like
# to leverage GPU parallelization capabilities, you will need to train
# with mini-batches.
#
# Using mini-batches also means that we must be mindful of the variation
# of sentence length in our batches. To accommodate sentences of different
# sizes in the same batch, we will make our batched input tensor of shape
# *(max_length, batch_size)*, where sentences shorter than the
# *max_length* are zero padded after an *EOS_token*.
#
# If we simply convert our English sentences to tensors by converting
# words to their indexes(\ ``indexesFromSentence``) and zero-pad, our
# tensor would have shape *(batch_size, max_length)* and indexing the
# first dimension would return a full sequence across all time-steps.
# However, we need to be able to index our batch along time, and across
# all sequences in the batch. Therefore, we transpose our input batch
# shape to *(max_length, batch_size)*, so that indexing across the first
# dimension returns a time step across all sentences in the batch. We
# handle this transpose implicitly in the ``zeroPadding`` function.
#
# .. figure:: /_static/img/chatbot/seq2seq_batches.png
#    :align: center
#    :alt: batches
#
# The ``inputVar`` function handles the process of converting sentences to
# tensor, ultimately creating a correctly shaped zero-padded tensor. It
# also returns a tensor of ``lengths`` for each of the sequences in the
# batch which will be passed to our decoder later.
#
# The ``outputVar`` function performs a similar function to ``inputVar``,
# but instead of returning a ``lengths`` tensor, it returns a binary mask
# tensor and a maximum target sentence length. The binary mask tensor has
# the same shape as the output target tensor, but every element that is a
# *PAD_token* is 0 and all others are 1.
#
# ``batch2TrainData`` simply takes a bunch of pairs and returns the input
# and target tensors using the aforementioned functions.

# %%
def indexesFromSentence(voc, sentence):
    return [voc.word2index[word] for word in sentence.split(' ')] + [EOS_token]


def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binaryMatrix(l, value=PAD_token):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

# Returns padded input sequence tensor and lengths
def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths

# Returns padded target sequence tensor, padding mask, and max target length
def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.BoolTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len

# Returns all items for a given batch of pairs
def batch2TrainData(voc, pair_batch):
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
    inp, lengths = inputVar(input_batch, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    return inp, lengths, output, mask, max_target_len


# Example for validation
small_batch_size = 5
batches = batch2TrainData(voc, [random.choice(pairs) for _ in range(small_batch_size)])
input_variable, lengths, target_variable, mask, max_target_len = batches

print("input_variable:", input_variable)
print("lengths:", lengths)
print("target_variable:", target_variable)
print("mask:", mask)
print("max_target_len:", max_target_len)
# Out:
# input_variable: tensor([[ 747,  747,    3,  167, 1085],
#         [1741,   16,   23,   23,   16],
#         [  22, 4353,   14, 4853, 4388],
#         [3409,   33,  452,  108, 4389],
#         [  16,  451,  441, 2204,   98],
#         [ 908,  422,  722,    2,    2],
#         [ 260,   33,    2,    0,    0],
#         [   9,  377,    0,    0,    0],
#         [3410,    2,    0,    0,    0],
#         [  16,    0,    0,    0,    0],
#         [3411,    0,    0,    0,    0],
#         [   2,    0,    0,    0,    0]])
# lengths: tensor([12,  9,  7,  6,  6])
# target_variable: tensor([[  20, 4353,   14,   12, 1778],
#         [ 159,   78,  687,  226, 4390],
#         [ 676,  650,  452, 4853,   19],
#         [3414,   65,  441,   28,  639],
#         [   4,  100,   28, 2417,  870],
#         [3335, 1843,  138,   52,   14],
#         [  30,  151,   22,  574,  402],
#         [1824,   13,   14,  181,   13],
#         [ 413,    2,  196, 1260,    2],
#         [  22,    0, 1733,  563,    0],
#         [3416,    0, 1734,   13,    0],
#         [ 742,    0, 1101,    2,    0],
#         [  13,    0,   13,    0,    0],
#         [   2,    0,    2,    0,    0]])
# mask: tensor([[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True, False,  True,  True, False],
#         [ True, False,  True,  True, False],
#         [ True, False,  True,  True, False],
#         [ True, False,  True, False, False],
#         [ True, False,  True, False, False]])
# max_target_len: 14

# %% [markdown]
# ## Define Models
#
# ### Seq2Seq Model
#
# The brains of our chatbot is a sequence-to-sequence (seq2seq) model. The
# goal of a seq2seq model is to take a variable-length sequence as an
# input, and return a variable-length sequence as an output using a
# fixed-sized model.
#
# [Sutskever et al.](https://arxiv.org/abs/1409.3215)_ discovered that
# by using two separate recurrent neural nets together, we can accomplish
# this task. One RNN acts as an **encoder**, which encodes a variable
# length input sequence to a fixed-length context vector. In theory, this
# context vector (the final hidden layer of the RNN) will contain semantic
# information about the query sentence that is input to the bot. The
# second RNN is a **decoder**, which takes an input word and the context
# vector, and returns a guess for the next word in the sequence and a
# hidden state to use in the next iteration.
#
# .. figure:: /_static/img/chatbot/seq2seq_ts.png
#    :align: center
#    :alt: model
#
# Image source:
# https://jeddy92.github.io/JEddy92.github.io/ts_seq2seq_intro/

# %% [markdown]
# ### Encoder
#
# The encoder RNN iterates through the input sentence one token
# (e.g. word) at a time, at each time step outputting an “output” vector
# and a “hidden state” vector. The hidden state vector is then passed to
# the next time step, while the output vector is recorded. The encoder
# transforms the context it saw at each point in the sequence into a set
# of points in a high-dimensional space, which the decoder will use to
# generate a meaningful output for the given task.
#
# At the heart of our encoder is a multi-layered Gated Recurrent Unit,
# invented by [Cho et al.](https://arxiv.org/pdf/1406.1078v3.pdf)_ in
# 2014. We will use a bidirectional variant of the GRU, meaning that there
# are essentially two independent RNNs: one that is fed the input sequence
# in normal sequential order, and one that is fed the input sequence in
# reverse order. The outputs of each network are summed at each time step.
# Using a bidirectional GRU will give us the advantage of encoding both
# past and future contexts.
#
# Bidirectional RNN:
#
# .. figure:: /_static/img/chatbot/RNN-bidirectional.png
#    :width: 70%
#    :align: center
#    :alt: rnn_bidir
#
# Image source: https://colah.github.io/posts/2015-09-NN-Types-FP/
#
# Note that an ``embedding`` layer is used to encode our word indices in
# an arbitrarily sized feature space. For our models, this layer will map
# each word to a feature space of size *hidden_size*. When trained, these
# values should encode semantic similarity between similar meaning words.
#
# Finally, if passing a padded batch of sequences to an RNN module, we
# must pack and unpack padding around the RNN pass using
# ``nn.utils.rnn.pack_padded_sequence`` and
# ``nn.utils.rnn.pad_packed_sequence`` respectively.
#
# **Computation Graph:**
#
#    1) Convert word indexes to embeddings.
#    2) Pack padded batch of sequences for RNN module.
#    3) Forward pass through GRU.
#    4) Unpack padding.
#    5) Sum bidirectional GRU outputs.
#    6) Return output and final hidden state.
#
# **Inputs:**
#
# -  ``input_seq``: batch of input sentences; shape=\ *(max_length,
#    batch_size)*
# -  ``input_lengths``: list of sentence lengths corresponding to each
#    sentence in the batch; shape=\ *(batch_size)*
# -  ``hidden``: hidden state; shape=\ *(n_layers x num_directions,
#    batch_size, hidden_size)*
#
# **Outputs:**
#
# -  ``outputs``: output features from the last hidden layer of the GRU
#    (sum of bidirectional outputs); shape=\ *(max_length, batch_size,
#    hidden_size)*
# -  ``hidden``: updated hidden state from GRU; shape=\ *(n_layers x
#    num_directions, batch_size, hidden_size)*

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Initialize GRU; the input_size and hidden_size params are both set to 'hidden_size'
        #   because our input size is a word embedding with number of features == hidden_size
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        # Pack padded batch of sequences for RNN module
        packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        # Return output and final hidden state
        return outputs, hidden

# %% [markdown]
# ### Decoder
#
# The decoder RNN generates the response sentence in a token-by-token
# fashion. It uses the encoder’s context vectors, and internal hidden
# states to generate the next word in the sequence. It continues
# generating words until it outputs an *EOS_token*, representing the end
# of the sentence. A common problem with a vanilla seq2seq decoder is that
# if we rely solely on the context vector to encode the entire input
# sequence’s meaning, it is likely that we will have information loss.
# This is especially the case when dealing with long input sequences,
# greatly limiting the capability of our decoder.
#
# To combat this, [Bahdanau et al.](https://arxiv.org/abs/1409.0473)_
# created an “attention mechanism” that allows the decoder to pay
# attention to certain parts of the input sequence, rather than using the
# entire fixed context at every step.
#
# At a high level, attention is calculated using the decoder’s current
# hidden state and the encoder’s outputs. The output attention weights
# have the same shape as the input sequence, allowing us to multiply them
# by the encoder outputs, giving us a weighted sum which indicates the
# parts of encoder output to pay attention to. [Sean
# Robertson’s](https://github.com/spro)_ figure describes this very
# well:
#
# .. figure:: /_static/img/chatbot/attn2.png
#    :align: center
#    :alt: attn2
#
# [Luong et al.](https://arxiv.org/abs/1508.04025)_ improved upon
# Bahdanau et al.’s groundwork by creating “Global attention”. The key
# difference is that with “Global attention”, we consider all of the
# encoder’s hidden states, as opposed to Bahdanau et al.’s “Local
# attention”, which only considers the encoder’s hidden state from the
# current time step. Another difference is that with “Global attention”,
# we calculate attention weights, or energies, using the hidden state of
# the decoder from the current time step only. Bahdanau et al.’s attention
# calculation requires knowledge of the decoder’s state from the previous
# time step. Also, Luong et al. provides various methods to calculate the
# attention energies between the encoder output and decoder output which
# are called “score functions”:
#
# .. figure:: /_static/img/chatbot/scores.png
#    :width: 60%
#    :align: center
#    :alt: scores
#
# where $h_t$ = current target decoder state and $\bar{h}_s$ =
# all encoder states.
#
# Overall, the Global attention mechanism can be summarized by the
# following figure. Note that we will implement the “Attention Layer” as a
# separate ``nn.Module`` called ``Attn``. The output of this module is a
# softmax normalized weights tensor of shape *(batch_size, 1,
# max_length)*.
#
# .. figure:: /_static/img/chatbot/global_attn.png
#    :align: center
#    :width: 60%
#    :alt: global_attn

# %%
# Luong attention layer
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()

        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %% [markdown]
# Now that we have defined our attention submodule, we can implement the
# actual decoder model. For the decoder, we will manually feed our batch
# one time step at a time. This means that our embedded word tensor and
# GRU output will both have shape *(1, batch_size, hidden_size)*.
#
# **Computation Graph:**
#
#    1) Get embedding of current input word.
#    2) Forward through unidirectional GRU.
#    3) Calculate attention weights from the current GRU output from (2).
#    4) Multiply attention weights to encoder outputs to get new "weighted sum" context vector.
#    5) Concatenate weighted context vector and GRU output using Luong eq. 5.
#    6) Predict next word using Luong eq. 6 (without softmax).
#    7) Return output and final hidden state.
#
# **Inputs:**
#
# -  ``input_step``: one time step (one word) of input sequence batch;
#    shape=\ *(1, batch_size)*
# -  ``last_hidden``: final hidden layer of GRU; shape=\ *(n_layers x
#    num_directions, batch_size, hidden_size)*
# -  ``encoder_outputs``: encoder model’s output; shape=\ *(max_length,
#    batch_size, hidden_size)*
#
# **Outputs:**
#
# -  ``output``: softmax normalized tensor giving probabilities of each
#    word being the correct next word in the decoded sequence;
#    shape=\ *(batch_size, voc.num_words)*
# -  ``hidden``: final hidden state of GRU; shape=\ *(n_layers x
#    num_directions, batch_size, hidden_size)*

# %%
class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        # Concatenate weighted context vector and GRU output using Luong eq. 5
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %% [markdown]
# ## Define Training Procedure
#
# ### Masked loss
#
# Since we are dealing with batches of padded sequences, we cannot simply
# consider all elements of the tensor when calculating loss. We define
# ``maskNLLLoss`` to calculate our loss based on our decoder’s output
# tensor, the target tensor, and a binary mask tensor describing the
# padding of the target tensor. This loss function calculates the average
# negative log likelihood of the elements that correspond to a *1* in the
# mask tensor.

# %%
def maskNLLLoss(inp, target, mask):
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()

# %% [markdown]
# ### Single training iteration
#
# The ``train`` function contains the algorithm for a single training
# iteration (a single batch of inputs).
#
# We will use a couple of clever tricks to aid in convergence:
#
# -  The first trick is using **teacher forcing**. This means that at some
#    probability, set by ``teacher_forcing_ratio``, we use the current
#    target word as the decoder’s next input rather than using the
#    decoder’s current guess. This technique acts as training wheels for
#    the decoder, aiding in more efficient training. However, teacher
#    forcing can lead to model instability during inference, as the
#    decoder may not have a sufficient chance to truly craft its own
#    output sequences during training. Thus, we must be mindful of how we
#    are setting the ``teacher_forcing_ratio``, and not be fooled by fast
#    convergence.
#
# -  The second trick that we implement is **gradient clipping**. This is
#    a commonly used technique for countering the “exploding gradient”
#    problem. In essence, by clipping or thresholding gradients to a
#    maximum value, we prevent the gradients from growing exponentially
#    and either overflow (NaN), or overshoot steep cliffs in the cost
#    function.
#
# .. figure:: /_static/img/chatbot/grad_clip.png
#    :align: center
#    :width: 60%
#    :alt: grad_clip
#
# Image source: Goodfellow et al. *Deep Learning*. 2016. https://www.deeplearningbook.org/
#
# **Sequence of Operations:**
#
#    1) Forward pass entire input batch through encoder.
#    2) Initialize decoder inputs as SOS_token, and hidden state as the encoder's final hidden state.
#    3) Forward input batch sequence through decoder one time step at a time.
#    4) If teacher forcing: set next decoder input as the current target; else: set next decoder input as current decoder output.
#    5) Calculate and accumulate loss.
#    6) Perform backpropagation.
#    7) Clip gradients.
#    8) Update encoder and decoder model parameters.
#
#
# .. Note ::
#
#   PyTorch’s RNN modules (``RNN``, ``LSTM``, ``GRU``) can be used like any
#   other non-recurrent layers by simply passing them the entire input
#   sequence (or batch of sequences). We use the ``GRU`` layer like this in
#   the ``encoder``. The reality is that under the hood, there is an
#   iterative process looping over each time step calculating hidden states.
#   Alternatively, you can run these modules one time-step at a time. In
#   this case, we manually loop over the sequences during the training
#   process like we must do for the ``decoder`` model. As long as you
#   maintain the correct conceptual model of these modules, implementing
#   sequential models can be very straightforward.

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for rnn packing should always be on the cpu
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropatation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

# %% [markdown]
# ### Training iterations
#
# It is finally time to tie the full training procedure together with the
# data. The ``trainIters`` function is responsible for running
# ``n_iterations`` of training given the passed models, optimizers, data,
# etc. This function is quite self explanatory, as we have done the heavy
# lifting with the ``train`` function.
#
# One thing to note is that when we save our model, we save a tarball
# containing the encoder and decoder state_dicts (parameters), the
# optimizers’ state_dicts, the loss, the iteration, etc. Saving the model
# in this way will give us the ultimate flexibility with the checkpoint.
# After loading a checkpoint, we will be able to use the model parameters
# to run inference, or we can continue training right where we left off.

# %%
def trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, clip, corpus_name, loadFilename):

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(iteration, iteration / n_iteration * 100, print_loss_avg))
            print_loss = 0

        # Save checkpoint
        if (iteration % save_every == 0):
            directory = os.path.join(save_dir, model_name, corpus_name, '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size))
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, '{}_{}.tar'.format(iteration, 'checkpoint')))

# %% [markdown]
# ## Define Evaluation
#
# After training a model, we want to be able to talk to the bot ourselves.
# First, we must define how we want the model to decode the encoded input.
#
# ### Greedy decoding
#
# Greedy decoding is the decoding method that we use during training when
# we are **NOT** using teacher forcing. In other words, for each time
# step, we simply choose the word from ``decoder_output`` with the highest
# softmax value. This decoding method is optimal on a single time-step
# level.
#
# To facilitate the greedy decoding operation, we define a
# ``GreedySearchDecoder`` class. When run, an object of this class takes
# an input sequence (``input_seq``) of shape *(input_seq length, 1)*, a
# scalar input length (``input_length``) tensor, and a ``max_length`` to
# bound the response sentence length. The input sentence is evaluated
# using the following computational graph:
#
# **Computation Graph:**
#
#    1) Forward input through encoder model.
#    2) Prepare encoder's final hidden layer to be first hidden input to the decoder.
#    3) Initialize decoder's first input as SOS_token.
#    4) Initialize tensors to append decoded words to.
#    5) Iteratively decode one word token at a time:
#        a) Forward pass through decoder.
#        b) Obtain most likely word token and its softmax score.
#        c) Record token and score.
#        d) Prepare current token to be next decoder input.
#    6) Return collections of word tokens and scores.

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %% [markdown]
# ### Evaluate my text
#
# Now that we have our decoding method defined, we can write functions for
# evaluating a string input sentence. The ``evaluate`` function manages
# the low-level process of handling the input sentence. We first format
# the sentence as an input batch of word indexes with *batch_size==1*. We
# do this by converting the words of the sentence to their corresponding
# indexes, and transposing the dimensions to prepare the tensor for our
# models. We also create a ``lengths`` tensor which contains the length of
# our input sentence. In this case, ``lengths`` is scalar because we are
# only evaluating one sentence at a time (batch_size==1). Next, we obtain
# the decoded response sentence tensor using our ``GreedySearchDecoder``
# object (``searcher``). Finally, we convert the response’s indexes to
# words and return the list of decoded words.
#
# ``evaluateInput`` acts as the user interface for our chatbot. When
# called, an input text field will spawn in which we can enter our query
# sentence. After typing our input sentence and pressing *Enter*, our text
# is normalized in the same way as our training data, and is ultimately
# fed to the ``evaluate`` function to obtain a decoded output sentence. We
# loop this process, so we can keep chatting with our bot until we enter
# either “q” or “quit”.
#
# Finally, if a sentence is entered that contains a word that is not in
# the vocabulary, we handle this gracefully by printing an error message
# and prompting the user to enter another sentence.

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    lengths = lengths.to("cpu")
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("I dont knowww!!!!.")

# %% [markdown]
# ## Run Model
#
# Finally, it is time to run our model!
#
# Regardless of whether we want to train or test the chatbot model, we
# must initialize the individual encoder and decoder models. In the
# following block, we set our desired configurations, choose to start from
# scratch or set a checkpoint to load from, and build and initialize the
# models. Feel free to play with different model configurations to
# optimize performance.

# %%
# Configure models
model_name = 'cb_model'
attn_model = 'dot'
#attn_model = 'general'
#attn_model = 'concat'
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64

# Set checkpoint to load from; set to None if starting from scratch
loadFilename = None
checkpoint_iter = 2000
#loadFilename = os.path.join(save_dir, model_name, corpus_name,
#                            '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
#                            '{}_checkpoint.tar'.format(checkpoint_iter))


# Load model if a loadFilename is provided
if loadFilename:
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %% [markdown]
# ### Run Training
#
# Run the following block if you want to train the model.
#
# First we set training parameters, then we initialize our optimizers, and
# finally we call the ``trainIters`` function to run our training
# iterations.

# %%
# Configure training/optimization
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iteration = 1000
print_every = 1
save_every = 500

# Ensure dropout layers are in train mode
encoder.train()
decoder.train()

# Initialize optimizers
print('Building optimizers ...')
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
if loadFilename:
    encoder_optimizer.load_state_dict(encoder_optimizer_sd)
    decoder_optimizer.load_state_dict(decoder_optimizer_sd)

# If you have cuda, configure cuda to call
for state in encoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

for state in decoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

# Run training iterations
print("Starting Training!")
trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
           embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
           print_every, save_every, clip, corpus_name, loadFilename)
# Out:
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 1; Percent complete: 0.1%; Average loss: 8.5151
# Iteration: 2; Percent complete: 0.2%; Average loss: 8.4501
# Iteration: 3; Percent complete: 0.3%; Average loss: 8.3665
# Iteration: 4; Percent complete: 0.4%; Average loss: 8.2121
# Iteration: 5; Percent complete: 0.5%; Average loss: 7.9773
# Iteration: 6; Percent complete: 0.6%; Average loss: 7.6968
# Iteration: 7; Percent complete: 0.7%; Average loss: 7.4031
# Iteration: 8; Percent complete: 0.8%; Average loss: 7.2156
# Iteration: 9; Percent complete: 0.9%; Average loss: 7.1017
# Iteration: 10; Percent complete: 1.0%; Average loss: 6.8385
# Iteration: 11; Percent complete: 1.1%; Average loss: 6.5134
# Iteration: 12; Percent complete: 1.2%; Average loss: 6.3938
# Iteration: 13; Percent complete: 1.3%; Average loss: 6.5101
# Iteration: 14; Percent complete: 1.4%; Average loss: 6.4573
# Iteration: 15; Percent complete: 1.5%; Average loss: 6.2651
# Iteration: 16; Percent complete: 1.6%; Average loss: 6.0866
# Iteration: 17; Percent complete: 1.7%; Average loss: 6.0322
# Iteration: 18; Percent complete: 1.8%; Average loss: 6.0200
# Iteration: 19; Percent complete: 1.9%; Average loss: 5.8069
# Iteration: 20; Percent complete: 2.0%; Average loss: 5.8717
# Iteration: 21; Percent complete: 2.1%; Average loss: 5.8686
# Iteration: 22; Percent complete: 2.2%; Average loss: 5.9262
# Iteration: 23; Percent complete: 2.3%; Average loss: 5.8699
# Iteration: 24; Percent complete: 2.4%; Average loss: 5.9513
# Iteration: 25; Percent complete: 2.5%; Average loss: 5.8728
# Iteration: 26; Percent complete: 2.6%; Average loss: 5.7782
# Iteration: 27; Percent complete: 2.7%; Average loss: 5.8151
# Iteration: 28; Percent complete: 2.8%; Average loss: 5.8390
# Iteration: 29; Percent complete: 2.9%; Average loss: 5.8964
# Iteration: 30; Percent complete: 3.0%; Average loss: 5.8624
# Iteration: 31; Percent complete: 3.1%; Average loss: 5.7526
# Iteration: 32; Percent complete: 3.2%; Average loss: 5.7262
# Iteration: 33; Percent complete: 3.3%; Average loss: 5.8610
# Iteration: 34; Percent complete: 3.4%; Average loss: 5.9736
# Iteration: 35; Percent complete: 3.5%; Average loss: 5.8904
# Iteration: 36; Percent complete: 3.6%; Average loss: 5.7747
# Iteration: 37; Percent complete: 3.7%; Average loss: 5.7805
# Iteration: 38; Percent complete: 3.8%; Average loss: 5.7604
# Iteration: 39; Percent complete: 3.9%; Average loss: 5.6703
# Iteration: 40; Percent complete: 4.0%; Average loss: 5.5744
# Iteration: 41; Percent complete: 4.1%; Average loss: 5.7456
# Iteration: 42; Percent complete: 4.2%; Average loss: 5.6630
# Iteration: 43; Percent complete: 4.3%; Average loss: 5.6137
# Iteration: 44; Percent complete: 4.4%; Average loss: 5.7209
# Iteration: 45; Percent complete: 4.5%; Average loss: 5.6149
# Iteration: 46; Percent complete: 4.6%; Average loss: 5.6339
# Iteration: 47; Percent complete: 4.7%; Average loss: 5.7002
# Iteration: 48; Percent complete: 4.8%; Average loss: 5.8899
# Iteration: 49; Percent complete: 4.9%; Average loss: 5.6360
# Iteration: 50; Percent complete: 5.0%; Average loss: 5.4658
# Iteration: 51; Percent complete: 5.1%; Average loss: 5.7556
# Iteration: 52; Percent complete: 5.2%; Average loss: 5.7406
# Iteration: 53; Percent complete: 5.3%; Average loss: 5.6297
# Iteration: 54; Percent complete: 5.4%; Average loss: 5.6395
# Iteration: 55; Percent complete: 5.5%; Average loss: 5.6235
# Iteration: 56; Percent complete: 5.6%; Average loss: 5.6041
# Iteration: 57; Percent complete: 5.7%; Average loss: 5.7488
# Iteration: 58; Percent complete: 5.8%; Average loss: 5.5866
# Iteration: 59; Percent complete: 5.9%; Average loss: 5.6323
# Iteration: 60; Percent complete: 6.0%; Average loss: 5.5445
# Iteration: 61; Percent complete: 6.1%; Average loss: 5.7456
# Iteration: 62; Percent complete: 6.2%; Average loss: 5.5684
# Iteration: 63; Percent complete: 6.3%; Average loss: 5.5899
# Iteration: 64; Percent complete: 6.4%; Average loss: 5.4536
# Iteration: 65; Percent complete: 6.5%; Average loss: 5.6817
# Iteration: 66; Percent complete: 6.6%; Average loss: 5.4685
# Iteration: 67; Percent complete: 6.7%; Average loss: 5.7115
# Iteration: 68; Percent complete: 6.8%; Average loss: 5.6585
# Iteration: 69; Percent complete: 6.9%; Average loss: 5.5914
# Iteration: 70; Percent complete: 7.0%; Average loss: 5.3804
# Iteration: 71; Percent complete: 7.1%; Average loss: 5.6725
# Iteration: 72; Percent complete: 7.2%; Average loss: 5.5119
# Iteration: 73; Percent complete: 7.3%; Average loss: 5.4669
# Iteration: 74; Percent complete: 7.4%; Average loss: 5.5316
# Iteration: 75; Percent complete: 7.5%; Average loss: 5.3756
# Iteration: 76; Percent complete: 7.6%; Average loss: 5.5047
# Iteration: 77; Percent complete: 7.7%; Average loss: 5.3874
# Iteration: 78; Percent complete: 7.8%; Average loss: 5.3023
# Iteration: 79; Percent complete: 7.9%; Average loss: 5.4957
# Iteration: 80; Percent complete: 8.0%; Average loss: 5.6376
# Iteration: 81; Percent complete: 8.1%; Average loss: 5.3604
# Iteration: 82; Percent complete: 8.2%; Average loss: 5.4921
# Iteration: 83; Percent complete: 8.3%; Average loss: 5.2589
# Iteration: 84; Percent complete: 8.4%; Average loss: 5.4976
# Iteration: 85; Percent complete: 8.5%; Average loss: 5.3336
# Iteration: 86; Percent complete: 8.6%; Average loss: 5.3125
# Iteration: 87; Percent complete: 8.7%; Average loss: 5.4690
# Iteration: 88; Percent complete: 8.8%; Average loss: 5.4593
# Iteration: 89; Percent complete: 8.9%; Average loss: 5.3107
# Iteration: 90; Percent complete: 9.0%; Average loss: 5.4456
# Iteration: 91; Percent complete: 9.1%; Average loss: 5.3728
# Iteration: 92; Percent complete: 9.2%; Average loss: 5.1438
# Iteration: 93; Percent complete: 9.3%; Average loss: 5.2688
# Iteration: 94; Percent complete: 9.4%; Average loss: 5.2785
# Iteration: 95; Percent complete: 9.5%; Average loss: 5.3419
# Iteration: 96; Percent complete: 9.6%; Average loss: 5.3101
# Iteration: 97; Percent complete: 9.7%; Average loss: 5.2073
# Iteration: 98; Percent complete: 9.8%; Average loss: 5.2891
# Iteration: 99; Percent complete: 9.9%; Average loss: 5.2312
# Iteration: 100; Percent complete: 10.0%; Average loss: 5.1613
# Iteration: 101; Percent complete: 10.1%; Average loss: 5.1390
# Iteration: 102; Percent complete: 10.2%; Average loss: 5.2373
# Iteration: 103; Percent complete: 10.3%; Average loss: 5.2618
# Iteration: 104; Percent complete: 10.4%; Average loss: 5.2886
# Iteration: 105; Percent complete: 10.5%; Average loss: 5.2479
# Iteration: 106; Percent complete: 10.6%; Average loss: 5.1661
# Iteration: 107; Percent complete: 10.7%; Average loss: 5.3140
# Iteration: 108; Percent complete: 10.8%; Average loss: 5.3086
# Iteration: 109; Percent complete: 10.9%; Average loss: 4.9728
# Iteration: 110; Percent complete: 11.0%; Average loss: 5.1447
# Iteration: 111; Percent complete: 11.1%; Average loss: 5.1550
# Iteration: 112; Percent complete: 11.2%; Average loss: 5.2524
# Iteration: 113; Percent complete: 11.3%; Average loss: 5.1978
# Iteration: 114; Percent complete: 11.4%; Average loss: 5.1482
# Iteration: 115; Percent complete: 11.5%; Average loss: 5.1742
# Iteration: 116; Percent complete: 11.6%; Average loss: 5.0324
# Iteration: 117; Percent complete: 11.7%; Average loss: 5.2161
# Iteration: 118; Percent complete: 11.8%; Average loss: 5.2564
# Iteration: 119; Percent complete: 11.9%; Average loss: 5.2369
# Iteration: 120; Percent complete: 12.0%; Average loss: 5.0437
# Iteration: 121; Percent complete: 12.1%; Average loss: 4.9952
# Iteration: 122; Percent complete: 12.2%; Average loss: 5.1611
# Iteration: 123; Percent complete: 12.3%; Average loss: 4.9803
# Iteration: 124; Percent complete: 12.4%; Average loss: 5.0694
# Iteration: 125; Percent complete: 12.5%; Average loss: 5.1989
# Iteration: 126; Percent complete: 12.6%; Average loss: 5.0155
# Iteration: 127; Percent complete: 12.7%; Average loss: 4.9843
# Iteration: 128; Percent complete: 12.8%; Average loss: 5.0754
# Iteration: 129; Percent complete: 12.9%; Average loss: 5.0274
# Iteration: 130; Percent complete: 13.0%; Average loss: 4.9785
# Iteration: 131; Percent complete: 13.1%; Average loss: 4.9893
# Iteration: 132; Percent complete: 13.2%; Average loss: 4.8878
# Iteration: 133; Percent complete: 13.3%; Average loss: 4.9235
# Iteration: 134; Percent complete: 13.4%; Average loss: 5.0722
# Iteration: 135; Percent complete: 13.5%; Average loss: 4.9606
# Iteration: 136; Percent complete: 13.6%; Average loss: 4.8913
# Iteration: 137; Percent complete: 13.7%; Average loss: 4.8778
# Iteration: 138; Percent complete: 13.8%; Average loss: 4.7982
# Iteration: 139; Percent complete: 13.9%; Average loss: 4.9814
# Iteration: 140; Percent complete: 14.0%; Average loss: 4.9758
# Iteration: 141; Percent complete: 14.1%; Average loss: 4.9367
# Iteration: 142; Percent complete: 14.2%; Average loss: 4.8714
# Iteration: 143; Percent complete: 14.3%; Average loss: 4.9578
# Iteration: 144; Percent complete: 14.4%; Average loss: 4.9976
# Iteration: 145; Percent complete: 14.5%; Average loss: 5.0711
# Iteration: 146; Percent complete: 14.6%; Average loss: 4.8657
# Iteration: 147; Percent complete: 14.7%; Average loss: 4.9394
# Iteration: 148; Percent complete: 14.8%; Average loss: 4.9264
# Iteration: 149; Percent complete: 14.9%; Average loss: 5.0795
# Iteration: 150; Percent complete: 15.0%; Average loss: 4.9105
# Iteration: 151; Percent complete: 15.1%; Average loss: 4.7805
# Iteration: 152; Percent complete: 15.2%; Average loss: 4.9675
# Iteration: 153; Percent complete: 15.3%; Average loss: 4.8490
# Iteration: 154; Percent complete: 15.4%; Average loss: 4.6734
# Iteration: 155; Percent complete: 15.5%; Average loss: 4.9484
# Iteration: 156; Percent complete: 15.6%; Average loss: 5.1569
# Iteration: 157; Percent complete: 15.7%; Average loss: 4.9174
# Iteration: 158; Percent complete: 15.8%; Average loss: 4.9724
# Iteration: 159; Percent complete: 15.9%; Average loss: 4.8858
# Iteration: 160; Percent complete: 16.0%; Average loss: 4.8042
# Iteration: 161; Percent complete: 16.1%; Average loss: 4.7919
# Iteration: 162; Percent complete: 16.2%; Average loss: 4.6030
# Iteration: 163; Percent complete: 16.3%; Average loss: 5.0356
# Iteration: 164; Percent complete: 16.4%; Average loss: 4.7756
# Iteration: 165; Percent complete: 16.5%; Average loss: 4.7585
# Iteration: 166; Percent complete: 16.6%; Average loss: 4.7432
# Iteration: 167; Percent complete: 16.7%; Average loss: 4.8748
# Iteration: 168; Percent complete: 16.8%; Average loss: 4.6377
# Iteration: 169; Percent complete: 16.9%; Average loss: 4.5427
# Iteration: 170; Percent complete: 17.0%; Average loss: 4.5314
# Iteration: 171; Percent complete: 17.1%; Average loss: 4.7164
# Iteration: 172; Percent complete: 17.2%; Average loss: 4.8230
# Iteration: 173; Percent complete: 17.3%; Average loss: 4.7439
# Iteration: 174; Percent complete: 17.4%; Average loss: 4.8516
# Iteration: 175; Percent complete: 17.5%; Average loss: 4.7600
# Iteration: 176; Percent complete: 17.6%; Average loss: 4.7227
# Iteration: 177; Percent complete: 17.7%; Average loss: 4.7689
# Iteration: 178; Percent complete: 17.8%; Average loss: 4.6662
# Iteration: 179; Percent complete: 17.9%; Average loss: 4.5695
# Iteration: 180; Percent complete: 18.0%; Average loss: 4.4641
# Iteration: 181; Percent complete: 18.1%; Average loss: 4.6938
# Iteration: 182; Percent complete: 18.2%; Average loss: 4.4152
# Iteration: 183; Percent complete: 18.3%; Average loss: 4.6477
# Iteration: 184; Percent complete: 18.4%; Average loss: 4.6818
# Iteration: 185; Percent complete: 18.5%; Average loss: 4.5596
# Iteration: 186; Percent complete: 18.6%; Average loss: 4.5748
# Iteration: 187; Percent complete: 18.7%; Average loss: 4.5594
# Iteration: 188; Percent complete: 18.8%; Average loss: 4.8844
# Iteration: 189; Percent complete: 18.9%; Average loss: 4.5603
# Iteration: 190; Percent complete: 19.0%; Average loss: 4.5481
# Iteration: 191; Percent complete: 19.1%; Average loss: 4.4585
# Iteration: 192; Percent complete: 19.2%; Average loss: 4.6197
# Iteration: 193; Percent complete: 19.3%; Average loss: 4.4348
# Iteration: 194; Percent complete: 19.4%; Average loss: 4.3929
# Iteration: 195; Percent complete: 19.5%; Average loss: 4.6001
# Iteration: 196; Percent complete: 19.6%; Average loss: 4.2678
# Iteration: 197; Percent complete: 19.7%; Average loss: 4.4943
# Iteration: 198; Percent complete: 19.8%; Average loss: 4.2890
# Iteration: 199; Percent complete: 19.9%; Average loss: 4.3920
# Iteration: 200; Percent complete: 20.0%; Average loss: 4.4135
# Iteration: 201; Percent complete: 20.1%; Average loss: 4.4594
# Iteration: 202; Percent complete: 20.2%; Average loss: 4.4551
# Iteration: 203; Percent complete: 20.3%; Average loss: 4.5597
# Iteration: 204; Percent complete: 20.4%; Average loss: 4.4204
# Iteration: 205; Percent complete: 20.5%; Average loss: 4.2688
# Iteration: 206; Percent complete: 20.6%; Average loss: 4.3077
# Iteration: 207; Percent complete: 20.7%; Average loss: 4.4786
# Iteration: 208; Percent complete: 20.8%; Average loss: 4.4379
# Iteration: 209; Percent complete: 20.9%; Average loss: 4.3591
# Iteration: 210; Percent complete: 21.0%; Average loss: 4.4419
# Iteration: 211; Percent complete: 21.1%; Average loss: 4.3094
# Iteration: 212; Percent complete: 21.2%; Average loss: 4.2404
# Iteration: 213; Percent complete: 21.3%; Average loss: 4.1506
# Iteration: 214; Percent complete: 21.4%; Average loss: 4.4982
# Iteration: 215; Percent complete: 21.5%; Average loss: 4.3760
# Iteration: 216; Percent complete: 21.6%; Average loss: 4.5777
# Iteration: 217; Percent complete: 21.7%; Average loss: 4.6121
# Iteration: 218; Percent complete: 21.8%; Average loss: 4.0983
# Iteration: 219; Percent complete: 21.9%; Average loss: 4.1706
# Iteration: 220; Percent complete: 22.0%; Average loss: 4.0806
# Iteration: 221; Percent complete: 22.1%; Average loss: 4.2293
# Iteration: 222; Percent complete: 22.2%; Average loss: 4.6134
# Iteration: 223; Percent complete: 22.3%; Average loss: 4.4829
# Iteration: 224; Percent complete: 22.4%; Average loss: 4.0899
# Iteration: 225; Percent complete: 22.5%; Average loss: 4.3192
# Iteration: 226; Percent complete: 22.6%; Average loss: 4.2916
# Iteration: 227; Percent complete: 22.7%; Average loss: 4.0196
# Iteration: 228; Percent complete: 22.8%; Average loss: 4.2581
# Iteration: 229; Percent complete: 22.9%; Average loss: 3.9341
# Iteration: 230; Percent complete: 23.0%; Average loss: 4.2838
# Iteration: 231; Percent complete: 23.1%; Average loss: 3.9900
# Iteration: 232; Percent complete: 23.2%; Average loss: 4.1215
# Iteration: 233; Percent complete: 23.3%; Average loss: 4.1405
# Iteration: 234; Percent complete: 23.4%; Average loss: 4.2016
# Iteration: 235; Percent complete: 23.5%; Average loss: 3.8309
# Iteration: 236; Percent complete: 23.6%; Average loss: 4.1857
# Iteration: 237; Percent complete: 23.7%; Average loss: 4.0710
# Iteration: 238; Percent complete: 23.8%; Average loss: 4.1901
# Iteration: 239; Percent complete: 23.9%; Average loss: 3.9888
# Iteration: 240; Percent complete: 24.0%; Average loss: 4.1852
# Iteration: 241; Percent complete: 24.1%; Average loss: 4.1418
# Iteration: 242; Percent complete: 24.2%; Average loss: 4.2494
# Iteration: 243; Percent complete: 24.3%; Average loss: 3.8262
# Iteration: 244; Percent complete: 24.4%; Average loss: 4.1585
# Iteration: 245; Percent complete: 24.5%; Average loss: 4.0784
# Iteration: 246; Percent complete: 24.6%; Average loss: 4.1977
# Iteration: 247; Percent complete: 24.7%; Average loss: 3.9459
# Iteration: 248; Percent complete: 24.8%; Average loss: 3.7818
# Iteration: 249; Percent complete: 24.9%; Average loss: 4.0348
# Iteration: 250; Percent complete: 25.0%; Average loss: 4.0087
# Iteration: 251; Percent complete: 25.1%; Average loss: 4.1290
# Iteration: 252; Percent complete: 25.2%; Average loss: 4.1566
# Iteration: 253; Percent complete: 25.3%; Average loss: 4.1092
# Iteration: 254; Percent complete: 25.4%; Average loss: 3.9725
# Iteration: 255; Percent complete: 25.5%; Average loss: 3.6897
# Iteration: 256; Percent complete: 25.6%; Average loss: 3.9052
# Iteration: 257; Percent complete: 25.7%; Average loss: 3.8185
# Iteration: 258; Percent complete: 25.8%; Average loss: 4.0566
# Iteration: 259; Percent complete: 25.9%; Average loss: 3.7594
# Iteration: 260; Percent complete: 26.0%; Average loss: 3.6852
# Iteration: 261; Percent complete: 26.1%; Average loss: 3.6605
# Iteration: 262; Percent complete: 26.2%; Average loss: 3.6835
# Iteration: 263; Percent complete: 26.3%; Average loss: 3.8836
# Iteration: 264; Percent complete: 26.4%; Average loss: 3.7682
# Iteration: 265; Percent complete: 26.5%; Average loss: 3.8179
# Iteration: 266; Percent complete: 26.6%; Average loss: 3.7853
# Iteration: 267; Percent complete: 26.7%; Average loss: 3.8450
# Iteration: 268; Percent complete: 26.8%; Average loss: 3.7455
# Iteration: 269; Percent complete: 26.9%; Average loss: 3.8952
# Iteration: 270; Percent complete: 27.0%; Average loss: 3.8273
# Iteration: 271; Percent complete: 27.1%; Average loss: 3.7150
# Iteration: 272; Percent complete: 27.2%; Average loss: 3.9509
# Iteration: 273; Percent complete: 27.3%; Average loss: 3.8192
# Iteration: 274; Percent complete: 27.4%; Average loss: 3.7862
# Iteration: 275; Percent complete: 27.5%; Average loss: 3.9316
# Iteration: 276; Percent complete: 27.6%; Average loss: 3.7317
# Iteration: 277; Percent complete: 27.7%; Average loss: 3.6177
# Iteration: 278; Percent complete: 27.8%; Average loss: 3.6753
# Iteration: 279; Percent complete: 27.9%; Average loss: 3.6109
# Iteration: 280; Percent complete: 28.0%; Average loss: 3.6611
# Iteration: 281; Percent complete: 28.1%; Average loss: 3.7360
# Iteration: 282; Percent complete: 28.2%; Average loss: 3.6798
# Iteration: 283; Percent complete: 28.3%; Average loss: 3.5203
# Iteration: 284; Percent complete: 28.4%; Average loss: 3.5215
# Iteration: 285; Percent complete: 28.5%; Average loss: 3.7921
# Iteration: 286; Percent complete: 28.6%; Average loss: 3.5736
# Iteration: 287; Percent complete: 28.7%; Average loss: 3.5999
# Iteration: 288; Percent complete: 28.8%; Average loss: 3.5855
# Iteration: 289; Percent complete: 28.9%; Average loss: 3.5307
# Iteration: 290; Percent complete: 29.0%; Average loss: 3.7204
# Iteration: 291; Percent complete: 29.1%; Average loss: 3.5448
# Iteration: 292; Percent complete: 29.2%; Average loss: 3.5496
# Iteration: 293; Percent complete: 29.3%; Average loss: 3.8032
# Iteration: 294; Percent complete: 29.4%; Average loss: 3.8292
# Iteration: 295; Percent complete: 29.5%; Average loss: 3.4232
# Iteration: 296; Percent complete: 29.6%; Average loss: 3.6689
# Iteration: 297; Percent complete: 29.7%; Average loss: 3.5408
# Iteration: 298; Percent complete: 29.8%; Average loss: 3.5998
# Iteration: 299; Percent complete: 29.9%; Average loss: 3.5661
# Iteration: 300; Percent complete: 30.0%; Average loss: 3.6549
# Iteration: 301; Percent complete: 30.1%; Average loss: 3.5664
# Iteration: 302; Percent complete: 30.2%; Average loss: 3.5250
# Iteration: 303; Percent complete: 30.3%; Average loss: 3.5617
# Iteration: 304; Percent complete: 30.4%; Average loss: 3.6360
# Iteration: 305; Percent complete: 30.5%; Average loss: 3.2871
# Iteration: 306; Percent complete: 30.6%; Average loss: 3.3662
# Iteration: 307; Percent complete: 30.7%; Average loss: 3.5162
# Iteration: 308; Percent complete: 30.8%; Average loss: 3.1763
# Iteration: 309; Percent complete: 30.9%; Average loss: 3.6148
# Iteration: 310; Percent complete: 31.0%; Average loss: 3.3261
# Iteration: 311; Percent complete: 31.1%; Average loss: 3.3606
# Iteration: 312; Percent complete: 31.2%; Average loss: 3.4618
# Iteration: 313; Percent complete: 31.3%; Average loss: 3.7842
# Iteration: 314; Percent complete: 31.4%; Average loss: 3.3341
# Iteration: 315; Percent complete: 31.5%; Average loss: 3.5573
# Iteration: 316; Percent complete: 31.6%; Average loss: 3.2295
# Iteration: 317; Percent complete: 31.7%; Average loss: 3.6913
# Iteration: 318; Percent complete: 31.8%; Average loss: 3.5496
# Iteration: 319; Percent complete: 31.9%; Average loss: 3.3711
# Iteration: 320; Percent complete: 32.0%; Average loss: 3.2696
# Iteration: 321; Percent complete: 32.1%; Average loss: 3.2904
# Iteration: 322; Percent complete: 32.2%; Average loss: 3.6021
# Iteration: 323; Percent complete: 32.3%; Average loss: 3.3847
# Iteration: 324; Percent complete: 32.4%; Average loss: 3.4139
# Iteration: 325; Percent complete: 32.5%; Average loss: 3.1423
# Iteration: 326; Percent complete: 32.6%; Average loss: 3.2702
# Iteration: 327; Percent complete: 32.7%; Average loss: 3.5025
# Iteration: 328; Percent complete: 32.8%; Average loss: 3.3316
# Iteration: 329; Percent complete: 32.9%; Average loss: 2.9952
# Iteration: 330; Percent complete: 33.0%; Average loss: 3.4396
# Iteration: 331; Percent complete: 33.1%; Average loss: 3.3889
# Iteration: 332; Percent complete: 33.2%; Average loss: 3.1785
# Iteration: 333; Percent complete: 33.3%; Average loss: 3.3511
# Iteration: 334; Percent complete: 33.4%; Average loss: 3.1350
# Iteration: 335; Percent complete: 33.5%; Average loss: 3.1507
# Iteration: 336; Percent complete: 33.6%; Average loss: 3.0262
# Iteration: 337; Percent complete: 33.7%; Average loss: 3.2650
# Iteration: 338; Percent complete: 33.8%; Average loss: 3.2165
# Iteration: 339; Percent complete: 33.9%; Average loss: 3.1010
# Iteration: 340; Percent complete: 34.0%; Average loss: 3.2105
# Iteration: 341; Percent complete: 34.1%; Average loss: 3.2757
# Iteration: 342; Percent complete: 34.2%; Average loss: 3.0046
# Iteration: 343; Percent complete: 34.3%; Average loss: 3.3050
# Iteration: 344; Percent complete: 34.4%; Average loss: 3.1654
# Iteration: 345; Percent complete: 34.5%; Average loss: 3.1752
# Iteration: 346; Percent complete: 34.6%; Average loss: 2.9919
# Iteration: 347; Percent complete: 34.7%; Average loss: 3.2003
# Iteration: 348; Percent complete: 34.8%; Average loss: 3.2465
# Iteration: 349; Percent complete: 34.9%; Average loss: 2.9707
# Iteration: 350; Percent complete: 35.0%; Average loss: 3.0426
# Iteration: 351; Percent complete: 35.1%; Average loss: 3.1078
# Iteration: 352; Percent complete: 35.2%; Average loss: 3.1833
# Iteration: 353; Percent complete: 35.3%; Average loss: 3.1303
# Iteration: 354; Percent complete: 35.4%; Average loss: 3.0406
# Iteration: 355; Percent complete: 35.5%; Average loss: 2.9770
# Iteration: 356; Percent complete: 35.6%; Average loss: 2.9882
# Iteration: 357; Percent complete: 35.7%; Average loss: 2.9594
# Iteration: 358; Percent complete: 35.8%; Average loss: 2.9658
# Iteration: 359; Percent complete: 35.9%; Average loss: 3.2456
# Iteration: 360; Percent complete: 36.0%; Average loss: 2.9907
# Iteration: 361; Percent complete: 36.1%; Average loss: 2.9883
# Iteration: 362; Percent complete: 36.2%; Average loss: 2.9861
# Iteration: 363; Percent complete: 36.3%; Average loss: 2.9972
# Iteration: 364; Percent complete: 36.4%; Average loss: 3.0898
# Iteration: 365; Percent complete: 36.5%; Average loss: 3.1094
# Iteration: 366; Percent complete: 36.6%; Average loss: 2.7954
# Iteration: 367; Percent complete: 36.7%; Average loss: 3.3528
# Iteration: 368; Percent complete: 36.8%; Average loss: 2.7761
# Iteration: 369; Percent complete: 36.9%; Average loss: 2.9993
# Iteration: 370; Percent complete: 37.0%; Average loss: 2.8776
# Iteration: 371; Percent complete: 37.1%; Average loss: 2.9186
# Iteration: 372; Percent complete: 37.2%; Average loss: 3.0448
# Iteration: 373; Percent complete: 37.3%; Average loss: 2.7437
# Iteration: 374; Percent complete: 37.4%; Average loss: 2.8510
# Iteration: 375; Percent complete: 37.5%; Average loss: 2.7568
# Iteration: 376; Percent complete: 37.6%; Average loss: 2.9256
# Iteration: 377; Percent complete: 37.7%; Average loss: 3.0031
# Iteration: 378; Percent complete: 37.8%; Average loss: 2.8495
# Iteration: 379; Percent complete: 37.9%; Average loss: 2.6210
# Iteration: 380; Percent complete: 38.0%; Average loss: 2.7308
# Iteration: 381; Percent complete: 38.1%; Average loss: 2.7815
# Iteration: 382; Percent complete: 38.2%; Average loss: 2.7043
# Iteration: 383; Percent complete: 38.3%; Average loss: 2.7006
# Iteration: 384; Percent complete: 38.4%; Average loss: 2.7410
# Iteration: 385; Percent complete: 38.5%; Average loss: 2.9059
# Iteration: 386; Percent complete: 38.6%; Average loss: 2.7107
# Iteration: 387; Percent complete: 38.7%; Average loss: 2.8505
# Iteration: 388; Percent complete: 38.8%; Average loss: 2.9270
# Iteration: 389; Percent complete: 38.9%; Average loss: 2.7277
# Iteration: 390; Percent complete: 39.0%; Average loss: 2.6700
# Iteration: 391; Percent complete: 39.1%; Average loss: 2.9022
# Iteration: 392; Percent complete: 39.2%; Average loss: 2.7314
# Iteration: 393; Percent complete: 39.3%; Average loss: 2.8184
# Iteration: 394; Percent complete: 39.4%; Average loss: 2.6545
# Iteration: 395; Percent complete: 39.5%; Average loss: 2.5702
# Iteration: 396; Percent complete: 39.6%; Average loss: 2.7005
# Iteration: 397; Percent complete: 39.7%; Average loss: 3.0533
# Iteration: 398; Percent complete: 39.8%; Average loss: 2.7957
# Iteration: 399; Percent complete: 39.9%; Average loss: 2.6655
# Iteration: 400; Percent complete: 40.0%; Average loss: 2.5098
# Iteration: 401; Percent complete: 40.1%; Average loss: 2.6307
# Iteration: 402; Percent complete: 40.2%; Average loss: 2.6553
# Iteration: 403; Percent complete: 40.3%; Average loss: 2.4077
# Iteration: 404; Percent complete: 40.4%; Average loss: 2.7610
# Iteration: 405; Percent complete: 40.5%; Average loss: 2.5442
# Iteration: 406; Percent complete: 40.6%; Average loss: 2.4225
# Iteration: 407; Percent complete: 40.7%; Average loss: 2.8348
# Iteration: 408; Percent complete: 40.8%; Average loss: 2.4709
# Iteration: 409; Percent complete: 40.9%; Average loss: 2.7551
# Iteration: 410; Percent complete: 41.0%; Average loss: 2.6943
# Iteration: 411; Percent complete: 41.1%; Average loss: 2.6000
# Iteration: 412; Percent complete: 41.2%; Average loss: 2.5542
# Iteration: 413; Percent complete: 41.3%; Average loss: 2.5182
# Iteration: 414; Percent complete: 41.4%; Average loss: 2.4829
# Iteration: 415; Percent complete: 41.5%; Average loss: 2.3931
# Iteration: 416; Percent complete: 41.6%; Average loss: 2.4164
# Iteration: 417; Percent complete: 41.7%; Average loss: 2.6589
# Iteration: 418; Percent complete: 41.8%; Average loss: 2.3638
# Iteration: 419; Percent complete: 41.9%; Average loss: 2.5439
# Iteration: 420; Percent complete: 42.0%; Average loss: 2.5558
# Iteration: 421; Percent complete: 42.1%; Average loss: 2.5682
# Iteration: 422; Percent complete: 42.2%; Average loss: 2.3428
# Iteration: 423; Percent complete: 42.3%; Average loss: 2.2713
# Iteration: 424; Percent complete: 42.4%; Average loss: 2.4663
# Iteration: 425; Percent complete: 42.5%; Average loss: 2.3471
# Iteration: 426; Percent complete: 42.6%; Average loss: 2.4941
# Iteration: 427; Percent complete: 42.7%; Average loss: 2.5819
# Iteration: 428; Percent complete: 42.8%; Average loss: 2.3451
# Iteration: 429; Percent complete: 42.9%; Average loss: 2.4812
# Iteration: 430; Percent complete: 43.0%; Average loss: 2.6704
# Iteration: 431; Percent complete: 43.1%; Average loss: 2.7160
# Iteration: 432; Percent complete: 43.2%; Average loss: 2.4652
# Iteration: 433; Percent complete: 43.3%; Average loss: 2.5074
# Iteration: 434; Percent complete: 43.4%; Average loss: 2.3722
# Iteration: 435; Percent complete: 43.5%; Average loss: 2.4179
# Iteration: 436; Percent complete: 43.6%; Average loss: 2.3909
# Iteration: 437; Percent complete: 43.7%; Average loss: 2.3132
# Iteration: 438; Percent complete: 43.8%; Average loss: 2.3081
# Iteration: 439; Percent complete: 43.9%; Average loss: 2.4867
# Iteration: 440; Percent complete: 44.0%; Average loss: 2.3012
# Iteration: 441; Percent complete: 44.1%; Average loss: 2.4431
# Iteration: 442; Percent complete: 44.2%; Average loss: 2.3182
# Iteration: 443; Percent complete: 44.3%; Average loss: 2.5935
# Iteration: 444; Percent complete: 44.4%; Average loss: 2.2894
# Iteration: 445; Percent complete: 44.5%; Average loss: 2.3504
# Iteration: 446; Percent complete: 44.6%; Average loss: 2.4796
# Iteration: 447; Percent complete: 44.7%; Average loss: 2.3913
# Iteration: 448; Percent complete: 44.8%; Average loss: 2.2118
# Iteration: 449; Percent complete: 44.9%; Average loss: 2.4047
# Iteration: 450; Percent complete: 45.0%; Average loss: 2.2619
# Iteration: 451; Percent complete: 45.1%; Average loss: 2.3079
# Iteration: 452; Percent complete: 45.2%; Average loss: 2.1735
# Iteration: 453; Percent complete: 45.3%; Average loss: 2.2349
# Iteration: 454; Percent complete: 45.4%; Average loss: 2.1609
# Iteration: 455; Percent complete: 45.5%; Average loss: 2.2749
# Iteration: 456; Percent complete: 45.6%; Average loss: 2.3716
# Iteration: 457; Percent complete: 45.7%; Average loss: 2.0095
# Iteration: 458; Percent complete: 45.8%; Average loss: 2.3454
# Iteration: 459; Percent complete: 45.9%; Average loss: 2.1666
# Iteration: 460; Percent complete: 46.0%; Average loss: 2.2662
# Iteration: 461; Percent complete: 46.1%; Average loss: 2.1176
# Iteration: 462; Percent complete: 46.2%; Average loss: 2.2321
# Iteration: 463; Percent complete: 46.3%; Average loss: 2.3199
# Iteration: 464; Percent complete: 46.4%; Average loss: 2.1616
# Iteration: 465; Percent complete: 46.5%; Average loss: 2.3510
# Iteration: 466; Percent complete: 46.6%; Average loss: 2.2581
# Iteration: 467; Percent complete: 46.7%; Average loss: 2.1560
# Iteration: 468; Percent complete: 46.8%; Average loss: 1.8952
# Iteration: 469; Percent complete: 46.9%; Average loss: 1.9907
# Iteration: 470; Percent complete: 47.0%; Average loss: 1.8727
# Iteration: 471; Percent complete: 47.1%; Average loss: 2.2779
# Iteration: 472; Percent complete: 47.2%; Average loss: 2.0618
# Iteration: 473; Percent complete: 47.3%; Average loss: 2.2810
# Iteration: 474; Percent complete: 47.4%; Average loss: 2.1177
# Iteration: 475; Percent complete: 47.5%; Average loss: 2.0909
# Iteration: 476; Percent complete: 47.6%; Average loss: 2.0665
# Iteration: 477; Percent complete: 47.7%; Average loss: 1.9829
# Iteration: 478; Percent complete: 47.8%; Average loss: 2.1038
# Iteration: 479; Percent complete: 47.9%; Average loss: 2.1761
# Iteration: 480; Percent complete: 48.0%; Average loss: 1.8694
# Iteration: 481; Percent complete: 48.1%; Average loss: 2.0077
# Iteration: 482; Percent complete: 48.2%; Average loss: 2.1221
# Iteration: 483; Percent complete: 48.3%; Average loss: 2.1674
# Iteration: 484; Percent complete: 48.4%; Average loss: 2.0220
# Iteration: 485; Percent complete: 48.5%; Average loss: 1.8823
# Iteration: 486; Percent complete: 48.6%; Average loss: 1.8902
# Iteration: 487; Percent complete: 48.7%; Average loss: 2.1402
# Iteration: 488; Percent complete: 48.8%; Average loss: 2.0105
# Iteration: 489; Percent complete: 48.9%; Average loss: 1.8808
# Iteration: 490; Percent complete: 49.0%; Average loss: 1.9486
# Iteration: 491; Percent complete: 49.1%; Average loss: 1.9218
# Iteration: 492; Percent complete: 49.2%; Average loss: 1.9362
# Iteration: 493; Percent complete: 49.3%; Average loss: 1.9056
# Iteration: 494; Percent complete: 49.4%; Average loss: 2.0140
# Iteration: 495; Percent complete: 49.5%; Average loss: 1.8758
# Iteration: 496; Percent complete: 49.6%; Average loss: 1.8372
# Iteration: 497; Percent complete: 49.7%; Average loss: 1.7492
# Iteration: 498; Percent complete: 49.8%; Average loss: 1.9278
# Iteration: 499; Percent complete: 49.9%; Average loss: 2.0282
# Iteration: 500; Percent complete: 50.0%; Average loss: 1.8496
# Iteration: 501; Percent complete: 50.1%; Average loss: 1.9739
# Iteration: 502; Percent complete: 50.2%; Average loss: 1.9205
# Iteration: 503; Percent complete: 50.3%; Average loss: 1.9910
# Iteration: 504; Percent complete: 50.4%; Average loss: 1.7322
# Iteration: 505; Percent complete: 50.5%; Average loss: 1.7540
# Iteration: 506; Percent complete: 50.6%; Average loss: 2.0149
# Iteration: 507; Percent complete: 50.7%; Average loss: 1.7515
# Iteration: 508; Percent complete: 50.8%; Average loss: 2.0041
# Iteration: 509; Percent complete: 50.9%; Average loss: 1.8552
# Iteration: 510; Percent complete: 51.0%; Average loss: 1.9121
# Iteration: 511; Percent complete: 51.1%; Average loss: 1.6148
# Iteration: 512; Percent complete: 51.2%; Average loss: 1.7817
# Iteration: 513; Percent complete: 51.3%; Average loss: 1.7515
# Iteration: 514; Percent complete: 51.4%; Average loss: 1.8665
# Iteration: 515; Percent complete: 51.5%; Average loss: 1.7108
# Iteration: 516; Percent complete: 51.6%; Average loss: 1.8800
# Iteration: 517; Percent complete: 51.7%; Average loss: 1.7181
# Iteration: 518; Percent complete: 51.8%; Average loss: 1.8865
# Iteration: 519; Percent complete: 51.9%; Average loss: 2.1902
# Iteration: 520; Percent complete: 52.0%; Average loss: 1.9129
# Iteration: 521; Percent complete: 52.1%; Average loss: 1.6897
# Iteration: 522; Percent complete: 52.2%; Average loss: 2.0112
# Iteration: 523; Percent complete: 52.3%; Average loss: 1.7513
# Iteration: 524; Percent complete: 52.4%; Average loss: 1.6554
# Iteration: 525; Percent complete: 52.5%; Average loss: 1.5746
# Iteration: 526; Percent complete: 52.6%; Average loss: 1.7835
# Iteration: 527; Percent complete: 52.7%; Average loss: 1.7947
# Iteration: 528; Percent complete: 52.8%; Average loss: 1.7766
# Iteration: 529; Percent complete: 52.9%; Average loss: 1.8441
# Iteration: 530; Percent complete: 53.0%; Average loss: 1.9570
# Iteration: 531; Percent complete: 53.1%; Average loss: 1.8574
# Iteration: 532; Percent complete: 53.2%; Average loss: 1.5068
# Iteration: 533; Percent complete: 53.3%; Average loss: 1.5431
# Iteration: 534; Percent complete: 53.4%; Average loss: 1.8381
# Iteration: 535; Percent complete: 53.5%; Average loss: 1.8570
# Iteration: 536; Percent complete: 53.6%; Average loss: 1.7979
# Iteration: 537; Percent complete: 53.7%; Average loss: 1.7055
# Iteration: 538; Percent complete: 53.8%; Average loss: 1.6798
# Iteration: 539; Percent complete: 53.9%; Average loss: 1.7571
# Iteration: 540; Percent complete: 54.0%; Average loss: 1.8243
# Iteration: 541; Percent complete: 54.1%; Average loss: 1.8199
# Iteration: 542; Percent complete: 54.2%; Average loss: 1.7022
# Iteration: 543; Percent complete: 54.3%; Average loss: 1.6772
# Iteration: 544; Percent complete: 54.4%; Average loss: 1.8576
# Iteration: 545; Percent complete: 54.5%; Average loss: 1.6623
# Iteration: 546; Percent complete: 54.6%; Average loss: 1.5476
# Iteration: 547; Percent complete: 54.7%; Average loss: 1.4496
# Iteration: 548; Percent complete: 54.8%; Average loss: 1.6975
# Iteration: 549; Percent complete: 54.9%; Average loss: 1.7183
# Iteration: 550; Percent complete: 55.0%; Average loss: 1.8123
# Iteration: 551; Percent complete: 55.1%; Average loss: 1.6986
# Iteration: 552; Percent complete: 55.2%; Average loss: 1.5658
# Iteration: 553; Percent complete: 55.3%; Average loss: 1.6548
# Iteration: 554; Percent complete: 55.4%; Average loss: 1.6288
# Iteration: 555; Percent complete: 55.5%; Average loss: 1.5965
# Iteration: 556; Percent complete: 55.6%; Average loss: 1.3137
# Iteration: 557; Percent complete: 55.7%; Average loss: 1.4876
# Iteration: 558; Percent complete: 55.8%; Average loss: 1.6599
# Iteration: 559; Percent complete: 55.9%; Average loss: 1.5899
# Iteration: 560; Percent complete: 56.0%; Average loss: 1.4927
# Iteration: 561; Percent complete: 56.1%; Average loss: 1.4046
# Iteration: 562; Percent complete: 56.2%; Average loss: 1.7346
# Iteration: 563; Percent complete: 56.3%; Average loss: 1.5105
# Iteration: 564; Percent complete: 56.4%; Average loss: 1.6053
# Iteration: 565; Percent complete: 56.5%; Average loss: 1.5742
# Iteration: 566; Percent complete: 56.6%; Average loss: 1.4828
# Iteration: 567; Percent complete: 56.7%; Average loss: 1.6066
# Iteration: 568; Percent complete: 56.8%; Average loss: 1.6063
# Iteration: 569; Percent complete: 56.9%; Average loss: 1.6913
# Iteration: 570; Percent complete: 57.0%; Average loss: 1.5769
# Iteration: 571; Percent complete: 57.1%; Average loss: 1.6432
# Iteration: 572; Percent complete: 57.2%; Average loss: 1.4448
# Iteration: 573; Percent complete: 57.3%; Average loss: 1.5436
# Iteration: 574; Percent complete: 57.4%; Average loss: 1.5283
# Iteration: 575; Percent complete: 57.5%; Average loss: 1.4548
# Iteration: 576; Percent complete: 57.6%; Average loss: 1.6050
# Iteration: 577; Percent complete: 57.7%; Average loss: 1.5614
# Iteration: 578; Percent complete: 57.8%; Average loss: 1.4382
# Iteration: 579; Percent complete: 57.9%; Average loss: 1.5014
# Iteration: 580; Percent complete: 58.0%; Average loss: 1.5626
# Iteration: 581; Percent complete: 58.1%; Average loss: 1.6190
# Iteration: 582; Percent complete: 58.2%; Average loss: 1.4584
# Iteration: 583; Percent complete: 58.3%; Average loss: 1.4848
# Iteration: 584; Percent complete: 58.4%; Average loss: 1.4209
# Iteration: 585; Percent complete: 58.5%; Average loss: 1.3160
# Iteration: 586; Percent complete: 58.6%; Average loss: 1.3664
# Iteration: 587; Percent complete: 58.7%; Average loss: 1.3717
# Iteration: 588; Percent complete: 58.8%; Average loss: 1.5080
# Iteration: 589; Percent complete: 58.9%; Average loss: 1.5791
# Iteration: 590; Percent complete: 59.0%; Average loss: 1.3884
# Iteration: 591; Percent complete: 59.1%; Average loss: 1.3806
# Iteration: 592; Percent complete: 59.2%; Average loss: 1.3999
# Iteration: 593; Percent complete: 59.3%; Average loss: 1.4228
# Iteration: 594; Percent complete: 59.4%; Average loss: 1.3561
# Iteration: 595; Percent complete: 59.5%; Average loss: 1.4056
# Iteration: 596; Percent complete: 59.6%; Average loss: 1.3074
# Iteration: 597; Percent complete: 59.7%; Average loss: 1.2467
# Iteration: 598; Percent complete: 59.8%; Average loss: 1.3952
# Iteration: 599; Percent complete: 59.9%; Average loss: 1.3765
# Iteration: 600; Percent complete: 60.0%; Average loss: 1.4508
# Iteration: 601; Percent complete: 60.1%; Average loss: 1.3005
# Iteration: 602; Percent complete: 60.2%; Average loss: 1.2232
# Iteration: 603; Percent complete: 60.3%; Average loss: 1.2733
# Iteration: 604; Percent complete: 60.4%; Average loss: 1.3024
# Iteration: 605; Percent complete: 60.5%; Average loss: 1.4970
# Iteration: 606; Percent complete: 60.6%; Average loss: 1.4730
# Iteration: 607; Percent complete: 60.7%; Average loss: 1.3409
# Iteration: 608; Percent complete: 60.8%; Average loss: 1.3267
# Iteration: 609; Percent complete: 60.9%; Average loss: 1.3444
# Iteration: 610; Percent complete: 61.0%; Average loss: 1.2382
# Iteration: 611; Percent complete: 61.1%; Average loss: 1.1322
# Iteration: 612; Percent complete: 61.2%; Average loss: 1.3411
# Iteration: 613; Percent complete: 61.3%; Average loss: 1.3899
# Iteration: 614; Percent complete: 61.4%; Average loss: 1.3328
# Iteration: 615; Percent complete: 61.5%; Average loss: 1.3604
# Iteration: 616; Percent complete: 61.6%; Average loss: 1.2764
# Iteration: 617; Percent complete: 61.7%; Average loss: 1.2639
# Iteration: 618; Percent complete: 61.8%; Average loss: 1.3515
# Iteration: 619; Percent complete: 61.9%; Average loss: 1.2926
# Iteration: 620; Percent complete: 62.0%; Average loss: 1.3267
# Iteration: 621; Percent complete: 62.1%; Average loss: 1.3324
# Iteration: 622; Percent complete: 62.2%; Average loss: 1.2746
# Iteration: 623; Percent complete: 62.3%; Average loss: 1.0702
# Iteration: 624; Percent complete: 62.4%; Average loss: 1.3404
# Iteration: 625; Percent complete: 62.5%; Average loss: 1.2718
# Iteration: 626; Percent complete: 62.6%; Average loss: 1.2916
# Iteration: 627; Percent complete: 62.7%; Average loss: 1.2894
# Iteration: 628; Percent complete: 62.8%; Average loss: 1.4000
# Iteration: 629; Percent complete: 62.9%; Average loss: 1.3027
# Iteration: 630; Percent complete: 63.0%; Average loss: 1.0478
# Iteration: 631; Percent complete: 63.1%; Average loss: 1.1549
# Iteration: 632; Percent complete: 63.2%; Average loss: 1.2628
# Iteration: 633; Percent complete: 63.3%; Average loss: 1.1630
# Iteration: 634; Percent complete: 63.4%; Average loss: 1.2246
# Iteration: 635; Percent complete: 63.5%; Average loss: 1.4322
# Iteration: 636; Percent complete: 63.6%; Average loss: 1.2013
# Iteration: 637; Percent complete: 63.7%; Average loss: 1.2560
# Iteration: 638; Percent complete: 63.8%; Average loss: 1.1024
# Iteration: 639; Percent complete: 63.9%; Average loss: 1.2971
# Iteration: 640; Percent complete: 64.0%; Average loss: 1.0398
# Iteration: 641; Percent complete: 64.1%; Average loss: 1.1184
# Iteration: 642; Percent complete: 64.2%; Average loss: 1.1351
# Iteration: 643; Percent complete: 64.3%; Average loss: 1.1377
# Iteration: 644; Percent complete: 64.4%; Average loss: 1.0617
# Iteration: 645; Percent complete: 64.5%; Average loss: 1.0740
# Iteration: 646; Percent complete: 64.6%; Average loss: 1.1221
# Iteration: 647; Percent complete: 64.7%; Average loss: 1.0664
# Iteration: 648; Percent complete: 64.8%; Average loss: 1.1061
# Iteration: 649; Percent complete: 64.9%; Average loss: 1.1805
# Iteration: 650; Percent complete: 65.0%; Average loss: 0.9148
# Iteration: 651; Percent complete: 65.1%; Average loss: 1.0600
# Iteration: 652; Percent complete: 65.2%; Average loss: 1.0959
# Iteration: 653; Percent complete: 65.3%; Average loss: 1.0598
# Iteration: 654; Percent complete: 65.4%; Average loss: 1.0404
# Iteration: 655; Percent complete: 65.5%; Average loss: 1.0489
# Iteration: 656; Percent complete: 65.6%; Average loss: 0.9910
# Iteration: 657; Percent complete: 65.7%; Average loss: 1.1516
# Iteration: 658; Percent complete: 65.8%; Average loss: 1.0212
# Iteration: 659; Percent complete: 65.9%; Average loss: 1.0157
# Iteration: 660; Percent complete: 66.0%; Average loss: 1.0425
# Iteration: 661; Percent complete: 66.1%; Average loss: 0.9904
# Iteration: 662; Percent complete: 66.2%; Average loss: 1.0397
# Iteration: 663; Percent complete: 66.3%; Average loss: 1.0459
# Iteration: 664; Percent complete: 66.4%; Average loss: 1.1146
# Iteration: 665; Percent complete: 66.5%; Average loss: 1.0641
# Iteration: 666; Percent complete: 66.6%; Average loss: 1.0226
# Iteration: 667; Percent complete: 66.7%; Average loss: 1.0530
# Iteration: 668; Percent complete: 66.8%; Average loss: 1.0854
# Iteration: 669; Percent complete: 66.9%; Average loss: 1.0156
# Iteration: 670; Percent complete: 67.0%; Average loss: 1.0334
# Iteration: 671; Percent complete: 67.1%; Average loss: 1.0479
# Iteration: 672; Percent complete: 67.2%; Average loss: 1.0801
# Iteration: 673; Percent complete: 67.3%; Average loss: 0.9955
# Iteration: 674; Percent complete: 67.4%; Average loss: 1.0012
# Iteration: 675; Percent complete: 67.5%; Average loss: 0.9897
# Iteration: 676; Percent complete: 67.6%; Average loss: 0.9834
# Iteration: 677; Percent complete: 67.7%; Average loss: 1.0032
# Iteration: 678; Percent complete: 67.8%; Average loss: 1.1315
# Iteration: 679; Percent complete: 67.9%; Average loss: 0.9289
# Iteration: 680; Percent complete: 68.0%; Average loss: 1.0446
# Iteration: 681; Percent complete: 68.1%; Average loss: 0.9050
# Iteration: 682; Percent complete: 68.2%; Average loss: 0.9119
# Iteration: 683; Percent complete: 68.3%; Average loss: 1.1494
# Iteration: 684; Percent complete: 68.4%; Average loss: 0.8607
# Iteration: 685; Percent complete: 68.5%; Average loss: 0.9701
# Iteration: 686; Percent complete: 68.6%; Average loss: 1.0246
# Iteration: 687; Percent complete: 68.7%; Average loss: 0.9225
# Iteration: 688; Percent complete: 68.8%; Average loss: 1.1180
# Iteration: 689; Percent complete: 68.9%; Average loss: 1.1402
# Iteration: 690; Percent complete: 69.0%; Average loss: 0.9980
# Iteration: 691; Percent complete: 69.1%; Average loss: 1.0035
# Iteration: 692; Percent complete: 69.2%; Average loss: 0.9562
# Iteration: 693; Percent complete: 69.3%; Average loss: 0.9365
# Iteration: 694; Percent complete: 69.4%; Average loss: 0.9304
# Iteration: 695; Percent complete: 69.5%; Average loss: 0.9039
# Iteration: 696; Percent complete: 69.6%; Average loss: 0.8630
# Iteration: 697; Percent complete: 69.7%; Average loss: 0.9267
# Iteration: 698; Percent complete: 69.8%; Average loss: 0.9068
# Iteration: 699; Percent complete: 69.9%; Average loss: 0.8309
# Iteration: 700; Percent complete: 70.0%; Average loss: 0.9674
# Iteration: 701; Percent complete: 70.1%; Average loss: 0.9478
# Iteration: 702; Percent complete: 70.2%; Average loss: 0.8258
# Iteration: 703; Percent complete: 70.3%; Average loss: 0.8128
# Iteration: 704; Percent complete: 70.4%; Average loss: 0.9345
# Iteration: 705; Percent complete: 70.5%; Average loss: 0.9745
# Iteration: 706; Percent complete: 70.6%; Average loss: 0.9920
# Iteration: 707; Percent complete: 70.7%; Average loss: 0.8516
# Iteration: 708; Percent complete: 70.8%; Average loss: 0.7849
# Iteration: 709; Percent complete: 70.9%; Average loss: 0.8281
# Iteration: 710; Percent complete: 71.0%; Average loss: 1.0046
# Iteration: 711; Percent complete: 71.1%; Average loss: 0.8755
# Iteration: 712; Percent complete: 71.2%; Average loss: 0.7682
# Iteration: 713; Percent complete: 71.3%; Average loss: 0.9213
# Iteration: 714; Percent complete: 71.4%; Average loss: 0.9119
# Iteration: 715; Percent complete: 71.5%; Average loss: 0.9542
# Iteration: 716; Percent complete: 71.6%; Average loss: 0.9196
# Iteration: 717; Percent complete: 71.7%; Average loss: 0.8021
# Iteration: 718; Percent complete: 71.8%; Average loss: 0.7954
# Iteration: 719; Percent complete: 71.9%; Average loss: 0.8461
# Iteration: 720; Percent complete: 72.0%; Average loss: 1.0847
# Iteration: 721; Percent complete: 72.1%; Average loss: 0.8201
# Iteration: 722; Percent complete: 72.2%; Average loss: 0.8549
# Iteration: 723; Percent complete: 72.3%; Average loss: 0.9245
# Iteration: 724; Percent complete: 72.4%; Average loss: 0.8853
# Iteration: 725; Percent complete: 72.5%; Average loss: 0.8848
# Iteration: 726; Percent complete: 72.6%; Average loss: 0.9135
# Iteration: 727; Percent complete: 72.7%; Average loss: 1.0030
# Iteration: 728; Percent complete: 72.8%; Average loss: 0.8491
# Iteration: 729; Percent complete: 72.9%; Average loss: 0.9387
# Iteration: 730; Percent complete: 73.0%; Average loss: 0.8108
# Iteration: 731; Percent complete: 73.1%; Average loss: 0.7885
# Iteration: 732; Percent complete: 73.2%; Average loss: 0.8170
# Iteration: 733; Percent complete: 73.3%; Average loss: 0.8700
# Iteration: 734; Percent complete: 73.4%; Average loss: 0.6592
# Iteration: 735; Percent complete: 73.5%; Average loss: 0.9041
# Iteration: 736; Percent complete: 73.6%; Average loss: 0.7779
# Iteration: 737; Percent complete: 73.7%; Average loss: 0.8488
# Iteration: 738; Percent complete: 73.8%; Average loss: 0.8277
# Iteration: 739; Percent complete: 73.9%; Average loss: 0.7343
# Iteration: 740; Percent complete: 74.0%; Average loss: 0.8584
# Iteration: 741; Percent complete: 74.1%; Average loss: 0.8049
# Iteration: 742; Percent complete: 74.2%; Average loss: 0.9094
# Iteration: 743; Percent complete: 74.3%; Average loss: 0.8437
# Iteration: 744; Percent complete: 74.4%; Average loss: 0.8246
# Iteration: 745; Percent complete: 74.5%; Average loss: 0.8786
# Iteration: 746; Percent complete: 74.6%; Average loss: 0.7962
# Iteration: 747; Percent complete: 74.7%; Average loss: 0.8514
# Iteration: 748; Percent complete: 74.8%; Average loss: 0.7245
# Iteration: 749; Percent complete: 74.9%; Average loss: 0.8565
# Iteration: 750; Percent complete: 75.0%; Average loss: 0.8021
# Iteration: 751; Percent complete: 75.1%; Average loss: 0.7990
# Iteration: 752; Percent complete: 75.2%; Average loss: 0.6806
# Iteration: 753; Percent complete: 75.3%; Average loss: 0.7912
# Iteration: 754; Percent complete: 75.4%; Average loss: 0.8109
# Iteration: 755; Percent complete: 75.5%; Average loss: 0.7903
# Iteration: 756; Percent complete: 75.6%; Average loss: 0.6563
# Iteration: 757; Percent complete: 75.7%; Average loss: 0.8403
# Iteration: 758; Percent complete: 75.8%; Average loss: 0.6896
# Iteration: 759; Percent complete: 75.9%; Average loss: 0.6839
# Iteration: 760; Percent complete: 76.0%; Average loss: 0.7696
# Iteration: 761; Percent complete: 76.1%; Average loss: 0.7999
# Iteration: 762; Percent complete: 76.2%; Average loss: 0.7480
# Iteration: 763; Percent complete: 76.3%; Average loss: 0.7383
# Iteration: 764; Percent complete: 76.4%; Average loss: 0.7181
# Iteration: 765; Percent complete: 76.5%; Average loss: 0.6950
# Iteration: 766; Percent complete: 76.6%; Average loss: 0.7793
# Iteration: 767; Percent complete: 76.7%; Average loss: 0.6800
# Iteration: 768; Percent complete: 76.8%; Average loss: 0.7227
# Iteration: 769; Percent complete: 76.9%; Average loss: 0.8859
# Iteration: 770; Percent complete: 77.0%; Average loss: 0.7664
# Iteration: 771; Percent complete: 77.1%; Average loss: 0.7045
# Iteration: 772; Percent complete: 77.2%; Average loss: 0.7388
# Iteration: 773; Percent complete: 77.3%; Average loss: 0.6524
# Iteration: 774; Percent complete: 77.4%; Average loss: 0.7665
# Iteration: 775; Percent complete: 77.5%; Average loss: 0.7470
# Iteration: 776; Percent complete: 77.6%; Average loss: 0.7779
# Iteration: 777; Percent complete: 77.7%; Average loss: 0.7064
# Iteration: 778; Percent complete: 77.8%; Average loss: 0.7757
# Iteration: 779; Percent complete: 77.9%; Average loss: 0.7573
# Iteration: 780; Percent complete: 78.0%; Average loss: 0.6854
# Iteration: 781; Percent complete: 78.1%; Average loss: 0.6110
# Iteration: 782; Percent complete: 78.2%; Average loss: 0.6208
# Iteration: 783; Percent complete: 78.3%; Average loss: 0.7375
# Iteration: 784; Percent complete: 78.4%; Average loss: 0.6971
# Iteration: 785; Percent complete: 78.5%; Average loss: 0.6204
# Iteration: 786; Percent complete: 78.6%; Average loss: 0.6311
# Iteration: 787; Percent complete: 78.7%; Average loss: 0.6988
# Iteration: 788; Percent complete: 78.8%; Average loss: 0.6846
# Iteration: 789; Percent complete: 78.9%; Average loss: 0.5841
# Iteration: 790; Percent complete: 79.0%; Average loss: 0.6868
# Iteration: 791; Percent complete: 79.1%; Average loss: 0.5395
# Iteration: 792; Percent complete: 79.2%; Average loss: 0.6184
# Iteration: 793; Percent complete: 79.3%; Average loss: 0.6810
# Iteration: 794; Percent complete: 79.4%; Average loss: 0.6813
# Iteration: 795; Percent complete: 79.5%; Average loss: 0.6938
# Iteration: 796; Percent complete: 79.6%; Average loss: 0.6336
# Iteration: 797; Percent complete: 79.7%; Average loss: 0.5818
# Iteration: 798; Percent complete: 79.8%; Average loss: 0.6189
# Iteration: 799; Percent complete: 79.9%; Average loss: 0.7061
# Iteration: 800; Percent complete: 80.0%; Average loss: 0.7103
# Iteration: 801; Percent complete: 80.1%; Average loss: 0.6588
# Iteration: 802; Percent complete: 80.2%; Average loss: 0.7031
# Iteration: 803; Percent complete: 80.3%; Average loss: 0.6393
# Iteration: 804; Percent complete: 80.4%; Average loss: 0.7029
# Iteration: 805; Percent complete: 80.5%; Average loss: 0.6989
# Iteration: 806; Percent complete: 80.6%; Average loss: 0.5860
# Iteration: 807; Percent complete: 80.7%; Average loss: 0.6837
# Iteration: 808; Percent complete: 80.8%; Average loss: 0.6164
# Iteration: 809; Percent complete: 80.9%; Average loss: 0.5881
# Iteration: 810; Percent complete: 81.0%; Average loss: 0.5712
# Iteration: 811; Percent complete: 81.1%; Average loss: 0.6553
# Iteration: 812; Percent complete: 81.2%; Average loss: 0.5610
# Iteration: 813; Percent complete: 81.3%; Average loss: 0.6879
# Iteration: 814; Percent complete: 81.4%; Average loss: 0.6382
# Iteration: 815; Percent complete: 81.5%; Average loss: 0.6991
# Iteration: 816; Percent complete: 81.6%; Average loss: 0.4990
# Iteration: 817; Percent complete: 81.7%; Average loss: 0.5247
# Iteration: 818; Percent complete: 81.8%; Average loss: 0.6107
# Iteration: 819; Percent complete: 81.9%; Average loss: 0.6775
# Iteration: 820; Percent complete: 82.0%; Average loss: 0.6710
# Iteration: 821; Percent complete: 82.1%; Average loss: 0.6178
# Iteration: 822; Percent complete: 82.2%; Average loss: 0.5444
# Iteration: 823; Percent complete: 82.3%; Average loss: 0.6101
# Iteration: 824; Percent complete: 82.4%; Average loss: 0.5688
# Iteration: 825; Percent complete: 82.5%; Average loss: 0.6263
# Iteration: 826; Percent complete: 82.6%; Average loss: 0.5922
# Iteration: 827; Percent complete: 82.7%; Average loss: 0.5484
# Iteration: 828; Percent complete: 82.8%; Average loss: 0.5943
# Iteration: 829; Percent complete: 82.9%; Average loss: 0.5330
# Iteration: 830; Percent complete: 83.0%; Average loss: 0.5216
# Iteration: 831; Percent complete: 83.1%; Average loss: 0.6475
# Iteration: 832; Percent complete: 83.2%; Average loss: 0.5879
# Iteration: 833; Percent complete: 83.3%; Average loss: 0.4673
# Iteration: 834; Percent complete: 83.4%; Average loss: 0.6132
# Iteration: 835; Percent complete: 83.5%; Average loss: 0.5798
# Iteration: 836; Percent complete: 83.6%; Average loss: 0.6388
# Iteration: 837; Percent complete: 83.7%; Average loss: 0.5979
# Iteration: 838; Percent complete: 83.8%; Average loss: 0.5661
# Iteration: 839; Percent complete: 83.9%; Average loss: 0.5567
# Iteration: 840; Percent complete: 84.0%; Average loss: 0.5578
# Iteration: 841; Percent complete: 84.1%; Average loss: 0.5385
# Iteration: 842; Percent complete: 84.2%; Average loss: 0.6265
# Iteration: 843; Percent complete: 84.3%; Average loss: 0.5315
# Iteration: 844; Percent complete: 84.4%; Average loss: 0.5034
# Iteration: 845; Percent complete: 84.5%; Average loss: 0.4546
# Iteration: 846; Percent complete: 84.6%; Average loss: 0.5396
# Iteration: 847; Percent complete: 84.7%; Average loss: 0.5944
# Iteration: 848; Percent complete: 84.8%; Average loss: 0.5753
# Iteration: 849; Percent complete: 84.9%; Average loss: 0.5646
# Iteration: 850; Percent complete: 85.0%; Average loss: 0.6046
# Iteration: 851; Percent complete: 85.1%; Average loss: 0.5243
# Iteration: 852; Percent complete: 85.2%; Average loss: 0.5550
# Iteration: 853; Percent complete: 85.3%; Average loss: 0.5109
# Iteration: 854; Percent complete: 85.4%; Average loss: 0.5439
# Iteration: 855; Percent complete: 85.5%; Average loss: 0.5429
# Iteration: 856; Percent complete: 85.6%; Average loss: 0.4754
# Iteration: 857; Percent complete: 85.7%; Average loss: 0.5111
# Iteration: 858; Percent complete: 85.8%; Average loss: 0.6010
# Iteration: 859; Percent complete: 85.9%; Average loss: 0.4931
# Iteration: 860; Percent complete: 86.0%; Average loss: 0.5291
# Iteration: 861; Percent complete: 86.1%; Average loss: 0.6083
# Iteration: 862; Percent complete: 86.2%; Average loss: 0.4975
# Iteration: 863; Percent complete: 86.3%; Average loss: 0.5274
# Iteration: 864; Percent complete: 86.4%; Average loss: 0.4874
# Iteration: 865; Percent complete: 86.5%; Average loss: 0.4948
# Iteration: 866; Percent complete: 86.6%; Average loss: 0.4646
# Iteration: 867; Percent complete: 86.7%; Average loss: 0.4906
# Iteration: 868; Percent complete: 86.8%; Average loss: 0.5830
# Iteration: 869; Percent complete: 86.9%; Average loss: 0.5002
# Iteration: 870; Percent complete: 87.0%; Average loss: 0.5093
# Iteration: 871; Percent complete: 87.1%; Average loss: 0.5639
# Iteration: 872; Percent complete: 87.2%; Average loss: 0.5462
# Iteration: 873; Percent complete: 87.3%; Average loss: 0.5044
# Iteration: 874; Percent complete: 87.4%; Average loss: 0.4837
# Iteration: 875; Percent complete: 87.5%; Average loss: 0.3857
# Iteration: 876; Percent complete: 87.6%; Average loss: 0.5279
# Iteration: 877; Percent complete: 87.7%; Average loss: 0.4660
# Iteration: 878; Percent complete: 87.8%; Average loss: 0.5240
# Iteration: 879; Percent complete: 87.9%; Average loss: 0.5232
# Iteration: 880; Percent complete: 88.0%; Average loss: 0.4422
# Iteration: 881; Percent complete: 88.1%; Average loss: 0.4543
# Iteration: 882; Percent complete: 88.2%; Average loss: 0.4024
# Iteration: 883; Percent complete: 88.3%; Average loss: 0.5097
# Iteration: 884; Percent complete: 88.4%; Average loss: 0.5274
# Iteration: 885; Percent complete: 88.5%; Average loss: 0.4339
# Iteration: 886; Percent complete: 88.6%; Average loss: 0.4730
# Iteration: 887; Percent complete: 88.7%; Average loss: 0.5174
# Iteration: 888; Percent complete: 88.8%; Average loss: 0.4913
# Iteration: 889; Percent complete: 88.9%; Average loss: 0.5160
# Iteration: 890; Percent complete: 89.0%; Average loss: 0.4250
# Iteration: 891; Percent complete: 89.1%; Average loss: 0.5519
# Iteration: 892; Percent complete: 89.2%; Average loss: 0.4606
# Iteration: 893; Percent complete: 89.3%; Average loss: 0.4925
# Iteration: 894; Percent complete: 89.4%; Average loss: 0.4505
# Iteration: 895; Percent complete: 89.5%; Average loss: 0.4322
# Iteration: 896; Percent complete: 89.6%; Average loss: 0.4195
# Iteration: 897; Percent complete: 89.7%; Average loss: 0.4838
# Iteration: 898; Percent complete: 89.8%; Average loss: 0.4602
# Iteration: 899; Percent complete: 89.9%; Average loss: 0.4209
# Iteration: 900; Percent complete: 90.0%; Average loss: 0.5395
# Iteration: 901; Percent complete: 90.1%; Average loss: 0.4877
# Iteration: 902; Percent complete: 90.2%; Average loss: 0.4257
# Iteration: 903; Percent complete: 90.3%; Average loss: 0.4256
# Iteration: 904; Percent complete: 90.4%; Average loss: 0.4242
# Iteration: 905; Percent complete: 90.5%; Average loss: 0.4031
# Iteration: 906; Percent complete: 90.6%; Average loss: 0.4264
# Iteration: 907; Percent complete: 90.7%; Average loss: 0.4389
# Iteration: 908; Percent complete: 90.8%; Average loss: 0.4442
# Iteration: 909; Percent complete: 90.9%; Average loss: 0.4397
# Iteration: 910; Percent complete: 91.0%; Average loss: 0.4008
# Iteration: 911; Percent complete: 91.1%; Average loss: 0.5138
# Iteration: 912; Percent complete: 91.2%; Average loss: 0.4131
# Iteration: 913; Percent complete: 91.3%; Average loss: 0.4799
# Iteration: 914; Percent complete: 91.4%; Average loss: 0.4671
# Iteration: 915; Percent complete: 91.5%; Average loss: 0.4608
# Iteration: 916; Percent complete: 91.6%; Average loss: 0.4316
# Iteration: 917; Percent complete: 91.7%; Average loss: 0.4297
# Iteration: 918; Percent complete: 91.8%; Average loss: 0.3988
# Iteration: 919; Percent complete: 91.9%; Average loss: 0.3840
# Iteration: 920; Percent complete: 92.0%; Average loss: 0.4228
# Iteration: 921; Percent complete: 92.1%; Average loss: 0.4577
# Iteration: 922; Percent complete: 92.2%; Average loss: 0.3921
# Iteration: 923; Percent complete: 92.3%; Average loss: 0.3812
# Iteration: 924; Percent complete: 92.4%; Average loss: 0.4296
# Iteration: 925; Percent complete: 92.5%; Average loss: 0.4240
# Iteration: 926; Percent complete: 92.6%; Average loss: 0.4822
# Iteration: 927; Percent complete: 92.7%; Average loss: 0.5141
# Iteration: 928; Percent complete: 92.8%; Average loss: 0.4448
# Iteration: 929; Percent complete: 92.9%; Average loss: 0.4390
# Iteration: 930; Percent complete: 93.0%; Average loss: 0.4425
# Iteration: 931; Percent complete: 93.1%; Average loss: 0.3855
# Iteration: 932; Percent complete: 93.2%; Average loss: 0.4224
# Iteration: 933; Percent complete: 93.3%; Average loss: 0.4225
# Iteration: 934; Percent complete: 93.4%; Average loss: 0.3768
# Iteration: 935; Percent complete: 93.5%; Average loss: 0.4183
# Iteration: 936; Percent complete: 93.6%; Average loss: 0.3957
# Iteration: 937; Percent complete: 93.7%; Average loss: 0.4437
# Iteration: 938; Percent complete: 93.8%; Average loss: 0.4232
# Iteration: 939; Percent complete: 93.9%; Average loss: 0.4562
# Iteration: 940; Percent complete: 94.0%; Average loss: 0.3498
# Iteration: 941; Percent complete: 94.1%; Average loss: 0.4098
# Iteration: 942; Percent complete: 94.2%; Average loss: 0.4142
# Iteration: 943; Percent complete: 94.3%; Average loss: 0.4047
# Iteration: 944; Percent complete: 94.4%; Average loss: 0.4494
# Iteration: 945; Percent complete: 94.5%; Average loss: 0.4377
# Iteration: 946; Percent complete: 94.6%; Average loss: 0.4327
# Iteration: 947; Percent complete: 94.7%; Average loss: 0.4170
# Iteration: 948; Percent complete: 94.8%; Average loss: 0.4848
# Iteration: 949; Percent complete: 94.9%; Average loss: 0.4391
# Iteration: 950; Percent complete: 95.0%; Average loss: 0.3779
# Iteration: 951; Percent complete: 95.1%; Average loss: 0.3723
# Iteration: 952; Percent complete: 95.2%; Average loss: 0.4372
# Iteration: 953; Percent complete: 95.3%; Average loss: 0.3859
# Iteration: 954; Percent complete: 95.4%; Average loss: 0.3710
# Iteration: 955; Percent complete: 95.5%; Average loss: 0.4214
# Iteration: 956; Percent complete: 95.6%; Average loss: 0.3730
# Iteration: 957; Percent complete: 95.7%; Average loss: 0.4294
# Iteration: 958; Percent complete: 95.8%; Average loss: 0.4603
# Iteration: 959; Percent complete: 95.9%; Average loss: 0.3979
# Iteration: 960; Percent complete: 96.0%; Average loss: 0.3494
# Iteration: 961; Percent complete: 96.1%; Average loss: 0.3857
# Iteration: 962; Percent complete: 96.2%; Average loss: 0.3655
# Iteration: 963; Percent complete: 96.3%; Average loss: 0.4216
# Iteration: 964; Percent complete: 96.4%; Average loss: 0.3984
# Iteration: 965; Percent complete: 96.5%; Average loss: 0.4437
# Iteration: 966; Percent complete: 96.6%; Average loss: 0.4371
# Iteration: 967; Percent complete: 96.7%; Average loss: 0.3510
# Iteration: 968; Percent complete: 96.8%; Average loss: 0.3502
# Iteration: 969; Percent complete: 96.9%; Average loss: 0.3552
# Iteration: 970; Percent complete: 97.0%; Average loss: 0.3683
# Iteration: 971; Percent complete: 97.1%; Average loss: 0.4206
# Iteration: 972; Percent complete: 97.2%; Average loss: 0.3854
# Iteration: 973; Percent complete: 97.3%; Average loss: 0.3742
# Iteration: 974; Percent complete: 97.4%; Average loss: 0.4109
# Iteration: 975; Percent complete: 97.5%; Average loss: 0.3923
# Iteration: 976; Percent complete: 97.6%; Average loss: 0.3930
# Iteration: 977; Percent complete: 97.7%; Average loss: 0.4157
# Iteration: 978; Percent complete: 97.8%; Average loss: 0.4040
# Iteration: 979; Percent complete: 97.9%; Average loss: 0.3532
# Iteration: 980; Percent complete: 98.0%; Average loss: 0.3760
# Iteration: 981; Percent complete: 98.1%; Average loss: 0.3874
# Iteration: 982; Percent complete: 98.2%; Average loss: 0.3791
# Iteration: 983; Percent complete: 98.3%; Average loss: 0.3965
# Iteration: 984; Percent complete: 98.4%; Average loss: 0.3819
# Iteration: 985; Percent complete: 98.5%; Average loss: 0.3899
# Iteration: 986; Percent complete: 98.6%; Average loss: 0.4170
# Iteration: 987; Percent complete: 98.7%; Average loss: 0.3666
# Iteration: 988; Percent complete: 98.8%; Average loss: 0.3821
# Iteration: 989; Percent complete: 98.9%; Average loss: 0.3819
# Iteration: 990; Percent complete: 99.0%; Average loss: 0.3522
# Iteration: 991; Percent complete: 99.1%; Average loss: 0.4043
# Iteration: 992; Percent complete: 99.2%; Average loss: 0.3151
# Iteration: 993; Percent complete: 99.3%; Average loss: 0.3248
# Iteration: 994; Percent complete: 99.4%; Average loss: 0.3267
# Iteration: 995; Percent complete: 99.5%; Average loss: 0.3592
# Iteration: 996; Percent complete: 99.6%; Average loss: 0.3318
# Iteration: 997; Percent complete: 99.7%; Average loss: 0.3587
# Iteration: 998; Percent complete: 99.8%; Average loss: 0.3647
# Iteration: 999; Percent complete: 99.9%; Average loss: 0.3210
# Iteration: 1000; Percent complete: 100.0%; Average loss: 0.3473

# %% [markdown]
# ### Run Evaluation
#
# To chat with model, run the following block.

# %%
# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# %%
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > what forms seasons
# Bot: the same is true of the southern hemisphere in november december and january .
# > When did the world war end?
# Bot: the war ended in victory for the allies . were extensively . were
# > what does a plus-minus sign mean
# Bot: the sign is normally pronounced plus or minus . of sign .
# > what kind of company is Microsoft ?
# Bot: it is also one of the world s most valuable companies .
# > whats my name
# I dont knowww!!!!.
# > quit
